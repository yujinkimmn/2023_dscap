# %%
import pandas as pd
import re
import demoji

# %%
# csv 불러오기
df1 = pd.read_csv('Documents/GitHub/2023_dscap/twitterdata/아편/아편_concat.csv', encoding = 'utf-8')
df2 = pd.read_csv('Documents/GitHub/2023_dscap/twitterdata/메스암페타민/메스암페타민_concat.csv', encoding = 'utf-8')

# %%
#url 제거

for i in range(len(df1)):
    text = df1['content'][i]
    text = re.sub(u'^https://', '', text)
    text = re.sub(u'[&gt;&lt;]', '', text)
    df1['content'][i] = text
# Out:
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/876726930.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['content'][i] = text

# %%
#url 제거

for i in range(len(df2)):
    text = df2['content'][i]
    text = re.sub(u'^https://', '', text)
    text = re.sub(u'[&gt;&lt;]', '', text)
    df2['content'][i] = text
# Out:
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/2111095318.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['content'][i] = text

# %%
df1

# %%
# 액센트 제거

def remove_accents(raw_text):
    """Removes common accent characters.

    """

    raw_text = re.sub(u"[àáâãäåạ]", 'a', raw_text)
    raw_text = re.sub(u"[èéêë]", 'e', raw_text)
    raw_text = re.sub(u"[ìíîï]", 'i', raw_text)
    raw_text = re.sub(u"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(u"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(u"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(u"[ß]", 'ss', raw_text)
    raw_text = re.sub(u"[ñ]", 'n', raw_text)
    raw_text = re.sub(u"[➍④]", '4', raw_text)
    raw_text = re.sub(u"𝒂𝒕𝒐", 'ato', raw_text)
    raw_text = re.sub(u"Аҳŗịṅḡ", 'Axring', raw_text)
    return raw_text

# %%
# 이모지 & 특수기호 제거

df1['content'] = df1['content'].str.replace(pat = r'[^\w]', repl = r' ', regex = True)

# %%
df1
# Out:
#      type1 type2              date            id    user.username  \
# 0       아편  스틸녹스   2022.8.21 01:16  1.561020e+18  slDmDMRHUlX2QKJ
# 1       아편  스틸녹스   2022.8.21 01:19  1.561030e+18  slDmDMRHUlX2QKJ
# 2       아편  스틸녹스   2022.8.27 15:39  1.563420e+18      dididio7890
# 3       아편  스틸녹스  2022.10.19 15:35  1.582620e+18  yunmise54753702
# 4       아편  스틸녹스  2022.10.20 22:52  1.583090e+18          _Hino_0
# ...    ...   ...               ...           ...              ...
# 1453    아편  트라마돌   2023.3.30 15:55  1.641330e+18      dsf51cv558e
# 1454    아편  트라마돌   2023.3.30 16:26  1.641340e+18        das2d88jc
# 1455    아편  트라마돌   2023.3.30 16:26  1.641340e+18          148cve0
# 1456    아편  트라마돌   2023.3.30 17:13  1.641350e+18      assh8e7rtcc
# 1457    아편  트라마돌   2023.3.30 17:57  1.641360e+18        Jhenbatar
#
#      user.displayname  place user.location  \
# 0                  ㅇㅇ    NaN           NaN
# 1                  ㅇㅇ    NaN           NaN
# 2             dididio    NaN           NaN
# 3                 윤미선    NaN           NaN
# 4               ㅌㅊㅅ히노    NaN       대한민국 울산
# ...               ...    ...           ...
# 1453              이사언    NaN           NaN
# 1454              신중철    NaN           NaN
# 1455              백민경    NaN           NaN
# 1456              정석훈    NaN           NaN
# 1457       Jhen batar    NaN           NaN
#
#                                                 content  likeCount  \
# 0                     수면제 구합니다   디엠주세요   졸피뎀  수면제  스틸녹스          0
# 1           스틸녹스 졸피뎀 구합니다   디엠주세요   졸피뎀  수면제  스틸녹스  졸끠뎀          0
# 2                              스틸녹스 구합니당      스틸녹스  졸피뎀          0
# 3     자낙스 판매하실 분 구해요      스틸녹스도 환영합니다   돈은 갯수보고 얼마든지...          0
# 4     자낙스 저한테 파실분 ㅠㅜㅜ급구팁이 ㅠㅜㅠㅜ뎸주세요오ㅠㅜㅠ    스틸녹스  자낙스 ...          2
# ...                                                 ...        ...
# 1453      Ｋạ톡           엑스터ㅅㅣ     하얀색 액체 정맥 전신 마취제 프...          0
# 1454   서울     정글주스 구입방법 트라마돌판매      비밀 배송 부산진    𝒂𝒕𝒐➍➍➍          0
# 1455      트라마돌 파는곳 비밀 배송 강동    흥분제판매       수면    𝒂𝒕𝒐➍➍➍          0
# 1456  예약  Аҳŗịṅḡ      Rush Poppers 판매     트라ㅁㅏ돌    최...          0
# 1457    오방약국 텔레그램  p i n k m a n 1 1 4        수면제사는법...          0
#
#       retweetCount  viewCount  \
# 0                0        NaN
# 1                0        NaN
# 2                0        NaN
# 3                0        NaN
# 4                0        NaN
# ...            ...        ...
# 1453             0      390.0
# 1454             0       70.0
# 1455             0       25.0
# 1456             0       63.0
# 1457             0       33.0
#
#                                                hashtags  \
# 0                                ['졸피뎀', '수면제', '스틸녹스']
# 1                         ['졸피뎀', '수면제', '스틸녹스', '졸끠뎀']
# 2                                       ['스틸녹스', '졸피뎀']
# 3     ['자낙스', '자낙스구함', '자낙스구매', '자낙스판매', '스틸녹스', '스틸...
# 4           ['스틸녹스', '자낙스', '자낙스구함', '자낙스판매', '스틸녹스판매']
# ...                                                 ...
# 1453                                          ['엑스터ㅅㅣ']
# 1454                                             ['서울']
# 1455                                             ['수면']
# 1456                                          ['트라ㅁㅏ돌']
# 1457                                          ['전국히로뽕']
#
#                                                   media          sourceLabel
# 0                                                   NaN  Twitter for Android
# 1                                                   NaN  Twitter for Android
# 2                                                   NaN      Twitter Web App
# 3                                                   NaN   Twitter for iPhone
# 4                                                   NaN  Twitter for Android
# ...                                                 ...                  ...
# 1453                                                NaN      Twitter Web App
# 1454                                                NaN      Twitter Web App
# 1455                                                NaN      Twitter Web App
# 1456                                                NaN      Twitter Web App
# 1457  [Photo(previewUrl='https://pbs.twimg.com/media...      Twitter Web App
#
# [1458 rows x 15 columns]

# %%
# 이모지 & 특수기호 제거

df2['content'] = df2['content'].str.replace(pat = r'[^\w]', repl = r' ', regex = True)

# %%
df2

# %%
#액센트 제거

for i in range(len(df1)):
    a = remove_accents(df1['content'][i])
    df1['content'][i] = a
    
# 중복된 띄어쓰기,줄바꿈을 띄어쓰기 1개로 전체 바꾸기
df1['content'] = df1['content'].str.replace('\s+', ' ')
# Out:
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/2784842239.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['content'][i] = a
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/2784842239.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['content'] = df1['content'].str.replace('\s+', ' ')

# %%
for i in range(len(df2)):
    a = remove_accents(df2['content'][i])
    df2['content'][i] = a
    
df2['content'] = df2['content'].str.replace('\s+', ' ')
# Out:
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/2665195205.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['content'][i] = a
# C:\Users\seonh\AppData\Local\Temp/ipykernel_13320/2665195205.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['content'] = df2['content'].str.replace('\s+', ' ')

# %%
df1.to_csv('Documents/GitHub/2023_dscap/twitterdata/아편/아편_demoji.csv', index = False)

# %%
df2.to_csv('Documents/GitHub/2023_dscap/twitterdata/메스암페타민/메스암페타민_demoji.csv', index = False)
