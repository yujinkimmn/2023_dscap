# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter    # 배열에서 각 원소 몇번 나오는지 알려줌
import ast
from matplotlib import rc 

# truncation 없이 출력
pd.set_option('display.max_colwidth', -1)
rc('font', family='AppleGothic')
# Out:
# /var/folders/yn/4yp008q55jv19mts19hw5lzc0000gn/T/ipykernel_14116/4099819176.py:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
GHB = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/GHB_tokenized.csv", encoding='utf-8')
LSD = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/LSD_tokenized.csv", encoding='utf-8')
MDMA = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/MDMA_tokenized.csv", encoding='utf-8')
기타 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/기타_tokenized.csv", encoding='utf-8')
대마 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/대마_tokenized.csv", encoding='utf-8')
메스암페타민 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/메스암페타민_tokenized.csv", encoding='utf-8')
사일로시빈 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/사일로시빈_tokenized.csv", encoding='utf-8')
아편 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/아편_tokenized.csv", encoding='utf-8')
알킬니트라이트 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/알킬니트라이트_tokenized.csv", encoding='utf-8')
케타민 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/케타민_tokenized.csv", encoding='utf-8')
코카인 = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/토큰화/코카인_tokenized.csv", encoding='utf-8')

df = pd.concat([GHB, LSD, MDMA, 기타, 대마, 메스암페타민, 사일로시빈, 아편, 알킬니트라이트, 케타민, 코카인], ignore_index=True)
df
# Out:
#       type1   type2                       date            id    user.username  \
# 0      GHB   발정제     2021-03-06 14:57:45+00:00  1.368210e+18  gije_cho
# 1      GHB   발정제     2021-03-12 14:39:17+00:00  1.370380e+18  Q54tEl2QSMCVIOI
# 2      GHB   최음제     2022-07-15 06:21:14+00:00  1.547830e+18  H1kUodcLjGk8bjR
# 3      GHB   물뽕      2022-08-08 22:34:46+00:00  1.556770e+18  jkmister11
# 4      GHB   물뽕      2022-08-13 06:12:40+00:00  1.558340e+18  Duckhoo101
# ...    ...   ..                            ...           ...         ...
# 31498  코카인   지역명코카인  2023-03-30 09:03:36+00:00  1.641370e+18  gg8644
# 31499  코카인   지역명코카인  2023-03-30 10:10:34+00:00  1.641380e+18  LMouraIndonesia
# 31500  코카인   지역명코카인  2023-03-30 10:12:03+00:00  1.641380e+18  milnerigbal
# 31501  코카인   지역명코카인  2023-03-30 18:34:46+00:00  1.641510e+18  gg8644
# 31502  코카인   지역명코카인  2023-03-30 18:39:22+00:00  1.641510e+18  hallo226
#
#       user.displayname place user.location  \
# 0      조기제              NaN   대한민국 서울
# 1      성빙               NaN   NaN
# 2      심상봉              NaN   NaN
# 3      Mister           NaN   NaN
# 4      꾸??¹⁴³           NaN   꼬레아
# ...       ...           ...    ...
# 31498  란                NaN   글쎄.
# 31499  Lucas Moura      NaN   NaN
# 31500  Igbal Milner     NaN   NaN
# 31501  란                NaN   글쎄.
# 31502  ヽ(*・ω・)ﾉ         NaN   NaN
#
#                                                                                                                                          content  \
# 0      카카오톡 EHKT 15 빻은 깨떨 먹고 3시 넘어서 작대기 소스를 만들었는데 발정제 후추를 더 넣어주면 구입 김치 겉잎으로 꽁치 한토막을 구매 오리는 와인숙성훈제오리더라고요 대마초 한식 이탈리아 스페인 태국 요리의 캔디 가능하다니 실화인가요 대마
# 1      카카오톡 EHKT 살아온 나의 노력이 떨 정확한 재료의 작대기 완벽하게 적응이 발정제 넣고 골고루 아이스 한국 야쿠르트 하이프레시 밀키트 작대기 두부김치해야겠어요 ' 대마초 캔디 여유롭게 만들어 보세요 대마
# 2      여성 최음제 판매 씨엘팜 비닉스 필름 구입 사이트 :
# 3      이슈 맛집 정보 피디수첩 클럽 유흥업소 범죄에 사용된 마약 GHB 물뽕 체내 검출 되지 않는 성분 오늘방송 다시보기
# 4      김학의 국민의당 특수강간범 물뽕 마약 박근혜 정부 법무부차관 검사출신
# ...                                       ...
# 31498  국가대표 coreaice 아이스작대기 코카인 작대기사용법 아이스얼음주사 인천아이스 허브 케이 아이스드랍 아이스작대기 클럽약 사탕 떨파는곳 엑스터시 떨판매 작대기 빙두 천안아이스 떨가격 서울아이스 떨판매 아이스술 아이스사는곳
# 31499  오방약국 텔레그램 pinkman114 경남드라퍼모집 코카인팝니다 파티마약하는법 케이팔아요 정글주스팔아요 창원드러그 댑
# 31500  오방약국 텔레그램 pinkman114 전라도아이스 밀크케타민도매 강동합성대마초 강남허브액상 창원엑시터시 아이스뽕하는법 코카인
# 31501  국가대표 coreaice 아이스작대기 코카인 판매처 아이스작대기 작대기주사 아이스뽕 케타민 아이스1G 사끼 엑스터시 떨사는곳 떨가격 떨팝니다 케타민 작대기술 서울아이스 빙두 필로폰파는곳 사티바 캔디판매처 케타민 아이스술 인증딜러
# 31502  텔레그램 JRice1 아이스작대기 무한 히로뽕 팝니다 반작대기 사끼 아이스작대기 케타민 엘에디 클럽파티 떨후기 떨파는곳 엑시 떨가격 차가운술 아이스얼음주사사용방법 아이스뽕 술구매 담배 마약효과 강남파티 아이스작대기 코카인
#
#        likeCount  retweetCount  viewCount  \
# 0      0.0        0.0          NaN
# 1      0.0        0.0          NaN
# 2      0.0        0.0          NaN
# 3      0.0        0.0          NaN
# 4      0.0        0.0          NaN
# ...    ...        ...           ..
# 31498  1.0        0.0           70.0
# 31499  0.0        0.0           52.0
# 31500  0.0        0.0           83.0
# 31501  0.0        0.0           41.0
# 31502  0.0        0.0           89.0
#
#                                                            hashtags  \
# 0      NaN
# 1      ['아이스', '작대기']
# 2      NaN
# 3      ['이슈', '맛집', '정보']
# 4      ['김학의', '국민의당', '특수강간범', '물뽕', '마약', '박근혜', '법무부차관', '검사출신']
# ...                                                             ...
# 31498  ['아이스술', '아이스사는곳']
# 31499  ['댑']
# 31500  ['코카인']
# 31501  ['아이스술', '인증딜러']
# 31502  ['아이스작대기', '코카인']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             media  \
# 0      NaN
# 1      [Photo(previewUrl='https://pbs.twimg.com/media/EwSU5EjVgAEq1gu?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/EwSU5EjVgAEq1gu?format=jpg&name=orig', altText=None)]
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 31498  [Photo(previewUrl='https://pbs.twimg.com/media/FsdNQNMaYAAgvOY?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FsdNQNMaYAAgvOY?format=jpg&name=orig', altText=None)]
# 31499  [Photo(previewUrl='https://pbs.twimg.com/media/Fsdck53aQAEKNbw?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/Fsdck53aQAEKNbw?format=jpg&name=orig', altText=None)]
# 31500  [Photo(previewUrl='https://pbs.twimg.com/media/Fsdc6fOakAASBp4?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/Fsdc6fOakAASBp4?format=jpg&name=orig', altText=None)]
# 31501  [Photo(previewUrl='https://pbs.twimg.com/media/FsfP-24akAAY5Q8?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FsfP-24akAAY5Q8?format=jpg&name=orig', altText=None)]
# 31502  [Video(thumbnailUrl='https://pbs.twimg.com/ext_tw_video_thumb/1641510427090915328/pu/img/unzCGHlvHisg9Z8F.jpg', variants=[VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/vid/480x640/O3jbH0l4bVCXU-AQ.mp4?tag=12', contentType='video/mp4', bitrate=950000), VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/pl/UdJmYxMIPbUECyuO.m3u8?tag=12&container=fmp4', contentType='application/x-mpegURL', bitrate=None), VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/vid/320x426/Cs4cTTvKd10n9rX_.mp4?tag=12', contentType='video/mp4', bitrate=632000)], duration=0.651, views=15, altText=None)]
#
#                sourceLabel  \
# 0      Twitter Web App
# 1      Twitter Web App
# 2      Twitter Web App
# 3      Tistory2Twitter
# 4      Twitter for Android
# ...                    ...
# 31498  Twitter Web App
# 31499  Twitter Web App
# 31500  Twitter Web App
# 31501  Twitter Web App
# 31502  Twitter Web App
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   okt  \
# 0      [('카카오', 'Noun'), ('톡', 'Noun'), ('EHKT', 'Alpha'), ('15', 'Number'), ('빻', 'Noun'), ('은', 'Josa'), ('깨', 'Noun'), ('떨', 'Verb'), ('먹고', 'Verb'), ('3시', 'Number'), ('넘어서', 'Verb'), ('작대기', 'Noun'), ('소스', 'Noun'), ('를', 'Josa'), ('만들었는데', 'Verb'), ('발정', 'Noun'), ('제', 'Noun'), ('후추', 'Noun'), ('를', 'Josa'), ('더', 'Noun'), ('넣어주면', 'Verb'), ('구입', 'Noun'), ('김치', 'Noun'), ('겉잎', 'Noun'), ('으로', 'Josa'), ('꽁치', 'Noun'), ('한', 'Determiner'), ('토막', 'Noun'), ('을', 'Josa'), ('구매', 'Noun'), ('오리', 'Noun'), ('는', 'Josa'), ('와인', 'Noun'), ('숙성', 'Noun'), ('훈제오리', 'Noun'), ('더라고요', 'Adjective'), ('대마초', 'Noun'), ('한식', 'Noun'), ('이탈리아', 'Noun'), ('스페인', 'Noun'), ('태국', 'Noun'), ('요리', 'Noun'), ('의', 'Josa'), ('캔디', 'Noun'), ('가능하다니', 'Adjective'), ('실화', 'Noun'), ('인가요', 'Josa'), ('대마', 'Noun')]
# 1      [('카카오', 'Noun'), ('톡', 'Noun'), ('EHKT', 'Alpha'), ('살아온', 'Verb'), ('나', 'Noun'), ('의', 'Josa'), ('노력', 'Noun'), ('이', 'Josa'), ('떨', 'Verb'), ('정확한', 'Adjective'), ('재료', 'Noun'), ('의', 'Josa'), ('작대기', 'Noun'), ('완벽하게', 'Adjective'), ('적응', 'Noun'), ('이', 'Josa'), ('발정', 'Noun'), ('제', 'Noun'), ('넣고', 'Verb'), ('골고루', 'Adverb'), ('아이스', 'Noun'), ('한국', 'Noun'), ('야쿠르트', 'Noun'), ('하이', 'Noun'), ('프레', 'Noun'), ('시', 'Noun'), ('밀', 'Noun'), ('키트', 'Noun'), ('작대기', 'Noun'), ('두부김치', 'Noun'), ('해야겠어요', 'Verb'), ("'", 'Punctuation'), ('대마초', 'Noun'), ('캔디', 'Noun'), ('여유롭게', 'Verb'), ('만들어', 'Verb'), ('보세요', 'Verb'), ('대마', 'Noun')]
# 2      [('여성', 'Noun'), ('최음제', 'Noun'), ('판매', 'Noun'), ('씨엘', 'Noun'), ('팜', 'Verb'), ('비', 'Noun'), ('닉스', 'Noun'), ('필름', 'Noun'), ('구입', 'Noun'), ('사이트', 'Noun'), (':', 'Punctuation')]
# 3      [('이슈', 'Noun'), ('맛집', 'Noun'), ('정보', 'Noun'), ('피디수첩', 'Noun'), ('클럽', 'Noun'), ('유흥업소', 'Noun'), ('범죄', 'Noun'), ('에', 'Josa'), ('사용', 'Noun'), ('된', 'Verb'), ('마약', 'Noun'), ('GHB', 'Alpha'), ('물뽕', 'Noun'), ('체내', 'Noun'), ('검', 'Noun'), ('출', 'Verb'), ('되지', 'Verb'), ('않는', 'Verb'), ('성분', 'Noun'), ('오늘', 'Noun'), ('방송', 'Noun'), ('다시', 'Noun'), ('보기', 'Noun')]
# 4      [('김학의', 'Noun'), ('국민의당', 'Noun'), ('특수', 'Noun'), ('강간범', 'Noun'), ('물뽕', 'Noun'), ('마약', 'Noun'), ('박근혜', 'Noun'), ('정부', 'Noun'), ('법무부', 'Noun'), ('차관', 'Noun'), ('검사', 'Noun'), ('출신', 'Noun')]
# ...                                                                                                                                                                                                       ...
# 31498  [('국가대표', 'Noun'), ('coreaice', 'Alpha'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('코카인', 'Noun'), ('작대기', 'Noun'), ('사', 'Modifier'), ('용법', 'Noun'), ('아이스', 'Noun'), ('얼음', 'Noun'), ('주사', 'Noun'), ('인천', 'Noun'), ('아이스', 'Noun'), ('허브', 'Noun'), ('케이', 'Noun'), ('아이스', 'Noun'), ('드랍', 'Noun'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('클럽', 'Noun'), ('약', 'Noun'), ('사탕', 'Noun'), ('떨', 'Verb'), ('파는', 'Verb'), ('곳', 'Noun'), ('엑스터시', 'Noun'), ('떨', 'Verb'), ('판매', 'Noun'), ('작대기', 'Noun'), ('빙', 'Noun'), ('두', 'Josa'), ('천안', 'Noun'), ('아이스', 'Noun'), ('떨', 'Verb'), ('가격', 'Noun'), ('서울', 'Noun'), ('아이스', 'Noun'), ('떨', 'Verb'), ('판매', 'Noun'), ('아이스', 'Noun'), ('술', 'Noun'), ('아이스', 'Noun'), ('사는', 'Verb'), ('곳', 'Noun')]
# 31499  [('오방', 'Noun'), ('약국', 'Noun'), ('텔레', 'Noun'), ('그램', 'Noun'), ('pinkman', 'Alpha'), ('114', 'Number'), ('경남', 'Noun'), ('드라퍼', 'Noun'), ('모집', 'Noun'), ('코카인', 'Noun'), ('팝니다', 'Verb'), ('파티마', 'Noun'), ('약하는', 'Adjective'), ('법', 'Noun'), ('케이', 'Noun'), ('팔아요', 'Verb'), ('정글', 'Noun'), ('주스', 'Noun'), ('팔아요', 'Verb'), ('창원', 'Noun'), ('드러', 'Adjective'), ('그', 'Determiner'), ('댑', 'Verb')]
# 31500  [('오방', 'Noun'), ('약국', 'Noun'), ('텔레', 'Noun'), ('그램', 'Noun'), ('pinkman', 'Alpha'), ('114', 'Number'), ('전라도', 'Noun'), ('아이스', 'Noun'), ('밀크', 'Noun'), ('케타민', 'Noun'), ('도매', 'Noun'), ('강동합', 'Adjective'), ('성', 'Modifier'), ('대마초', 'Noun'), ('강남', 'Noun'), ('허브', 'Noun'), ('액', 'Noun'), ('상', 'Suffix'), ('창원', 'Noun'), ('엑시터', 'Noun'), ('시', 'Noun'), ('아이스', 'Noun'), ('뽕', 'Noun'), ('하', 'Suffix'), ('는', 'Josa'), ('법', 'Noun'), ('코카인', 'Noun')]
# 31501  [('국가대표', 'Noun'), ('coreaice', 'Alpha'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('코카인', 'Noun'), ('판매', 'Noun'), ('처', 'Noun'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('작대기', 'Noun'), ('주사', 'Noun'), ('아이스', 'Noun'), ('뽕', 'Noun'), ('케타민', 'Noun'), ('아이스', 'Noun'), ('1', 'Number'), ('G', 'Alpha'), ('사', 'Modifier'), ('끼', 'Noun'), ('엑스터시', 'Noun'), ('떨', 'Verb'), ('사는', 'Verb'), ('곳', 'Noun'), ('떨', 'Verb'), ('가격', 'Noun'), ('떨', 'Verb'), ('팝니다', 'Verb'), ('케타민', 'Noun'), ('작', 'Modifier'), ('대', 'Modifier'), ('기술', 'Noun'), ('서울', 'Noun'), ('아이스', 'Noun'), ('빙', 'Noun'), ('두', 'Josa'), ('필로폰', 'Noun'), ('파는', 'Verb'), ('곳', 'Noun'), ('사', 'Modifier'), ('티바', 'Noun'), ('캔디', 'Noun'), ('판매', 'Noun'), ('처', 'Noun'), ('케타민', 'Noun'), ('아이스', 'Noun'), ('술', 'Noun'), ('인증', 'Noun'), ('딜러', 'Noun')]
# 31502  [('텔레', 'Noun'), ('그램', 'Noun'), ('JRice', 'Alpha'), ('1', 'Number'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('무한', 'Noun'), ('히로뽕', 'Noun'), ('팝니다', 'Verb'), ('반작대기', 'Verb'), ('사', 'Modifier'), ('끼', 'Noun'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('케타민', 'Noun'), ('엘', 'Noun'), ('에디', 'Noun'), ('클럽', 'Noun'), ('파티', 'Noun'), ('떨', 'Verb'), ('후기', 'Noun'), ('떨', 'Verb'), ('파는', 'Verb'), ('곳', 'Noun'), ('엑', 'Exclamation'), ('시', 'Noun'), ('떨', 'Verb'), ('가격', 'Noun'), ('차가운', 'Adjective'), ('술', 'Noun'), ('아이스', 'Noun'), ('얼음', 'Noun'), ('주사', 'Noun'), ('사용', 'Noun'), ('방법', 'Noun'), ('아이스', 'Noun'), ('뽕', 'Noun'), ('술', 'Noun'), ('구매', 'Noun'), ('담배', 'Noun'), ('마약', 'Noun'), ('효과', 'Noun'), ('강남', 'Noun'), ('파티', 'Noun'), ('아이스', 'Noun'), ('작대기', 'Noun'), ('코카인', 'Noun')]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              komoran  \
# 0      [('카카오톡', 'NNP'), ('EHKT', 'SL'), ('15', 'SN'), ('빻', 'VV'), ('은', 'ETM'), ('깨', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('먹', 'VV'), ('고', 'EC'), ('3', 'SN'), ('시', 'NNB'), ('넘', 'VV'), ('어서', 'EC'), ('작대기', 'NNG'), ('소스', 'NNP'), ('를', 'JKO'), ('만들', 'VV'), ('었', 'EP'), ('는데', 'EC'), ('발', 'NNG'), ('정제', 'NNP'), ('후추', 'NNP'), ('를', 'JKO'), ('더', 'MAG'), ('넣', 'VV'), ('어', 'EC'), ('주', 'VX'), ('면', 'EC'), ('구입', 'NNG'), ('김치', 'NNP'), ('겉', 'NNG'), ('잎', 'NNG'), ('으로', 'JKB'), ('꽁치', 'NNP'), ('한', 'MM'), ('토막', 'NNP'), ('을', 'JKO'), ('구매', 'NNG'), ('오리', 'NNP'), ('는', 'JX'), ('와인', 'NNP'), ('숙성', 'NNP'), ('훈제', 'NNP'), ('오리', 'VV'), ('더라고요', 'EC'), ('대마초', 'NNP'), ('한식', 'NNP'), ('이탈리아', 'NNP'), ('스페인', 'NNP'), ('태국', 'NNP'), ('요리', 'NNP'), ('의', 'JKG'), ('캔디', 'NNP'), ('가능', 'XR'), ('하', 'XSA'), ('다니', 'EC'), ('실화', 'NNG'), ('이', 'VCP'), ('ㄴ가요', 'EC'), ('대마', 'NNG')]
# 1      [('카카오톡', 'NNP'), ('EHKT', 'SL'), ('살아오', 'VV'), ('ㄴ', 'ETM'), ('나', 'NP'), ('의', 'JKG'), ('노력', 'NNG'), ('이', 'JKS'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('정확', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('재료', 'NNP'), ('의', 'JKG'), ('작대기', 'NNG'), ('완벽', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('적응', 'NNG'), ('이', 'JKS'), ('발', 'NNG'), ('정제', 'NNP'), ('넣', 'VV'), ('고', 'EC'), ('골고루', 'MAG'), ('아이스', 'NNP'), ('한국', 'NNP'), ('야쿠르트', 'NNP'), ('하', 'NNG'), ('이프', 'NNP'), ('레시', 'NNP'), ('밀', 'NNP'), ('키트', 'NNP'), ('작대기', 'NNG'), ('두부김치', 'NNP'), ('하', 'XSV'), ('아야', 'EC'), ('하', 'VX'), ('겠', 'EP'), ('어요', 'EC'), ("'", 'SS'), ('대마초', 'NNP'), ('캔디', 'NNP'), ('여유', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('만들', 'VV'), ('어', 'EC'), ('보', 'VV'), ('시', 'EP'), ('어요', 'EC'), ('대마', 'NNG')]
# 2      [('여성', 'NNG'), ('최', 'XPN'), ('음', 'NNG'), ('제', 'XSN'), ('판매', 'NNG'), ('씨', 'NNB'), ('엘', 'NNP'), ('파', 'VV'), ('ㅁ', 'ETN'), ('비', 'XPN'), ('닉스', 'NNP'), ('필름', 'NNP'), ('구입', 'NNG'), ('사이트', 'NNG'), (':', 'SP')]
# 3      [('이슈', 'NNG'), ('맛집', 'NNG'), ('정보', 'NNG'), ('피디', 'NNG'), ('수첩', 'NNP'), ('클럽', 'NNP'), ('유흥업소', 'NNG'), ('범죄', 'NNG'), ('에', 'JKB'), ('사용', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETM'), ('마약', 'NNP'), ('GHB', 'SL'), ('물', 'NNG'), ('뽕', 'NNG'), ('체내', 'NNG'), ('검출', 'NNG'), ('되', 'VV'), ('지', 'EC'), ('않', 'VX'), ('는', 'ETM'), ('성분', 'NNG'), ('오늘', 'NNG'), ('방송', 'NNP'), ('다시', 'NNP'), ('보기', 'NNP')]
# 4      [('김학의', 'NNP'), ('국민의당', 'NNP'), ('특수', 'NNP'), ('강간', 'NNP'), ('범', 'NNG'), ('물', 'NNG'), ('뽕', 'NNG'), ('마약', 'NNP'), ('박근혜 정부', 'NNP'), ('법무부', 'NNP'), ('차관', 'NNP'), ('검사', 'NNG'), ('출신', 'NNG')]
# ...                                                                                                                                                                                                         ...
# 31498  [('국가대표', 'NNP'), ('coreaice', 'SL'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('코카인', 'NNP'), ('작대기', 'NNG'), ('사용법', 'NNG'), ('아이스', 'NNP'), ('얼음', 'NNP'), ('주사', 'NNP'), ('인천', 'NNP'), ('아이스', 'NNP'), ('허브', 'NNP'), ('케이', 'NNP'), ('아이스드랍', 'NA'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('클럽', 'NNP'), ('약', 'MM'), ('사탕', 'NNP'), ('떨', 'VV'), ('팔', 'VV'), ('는', 'ETM'), ('곳', 'NNG'), ('엑스터시', 'NNP'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('판매', 'NNP'), ('작대기', 'NNG'), ('빙', 'MAG'), ('두', 'JX'), ('천안', 'NNP'), ('아이스', 'NNP'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('가격', 'NNP'), ('서울', 'NNP'), ('아이스', 'NNP'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('판매', 'NNP'), ('아이스', 'NNP'), ('술', 'NNG'), ('아이스', 'NNG'), ('살', 'VV'), ('는', 'ETM'), ('곳', 'NNG')]
# 31499  [('오방', 'NNP'), ('약국', 'NNP'), ('텔레그램', 'NNP'), ('pinkman', 'SL'), ('114', 'NNP'), ('경남', 'NNP'), ('들', 'VV'), ('라', 'EC'), ('푸', 'VV'), ('어', 'EC'), ('모집', 'NNG'), ('코카인', 'NNP'), ('팝', 'NNG'), ('니다', 'NNP'), ('파티마', 'NNP'), ('약', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('법', 'NNB'), ('케이', 'NNP'), ('팔', 'VV'), ('아요', 'EC'), ('정글', 'NNP'), ('주스', 'NNP'), ('팔', 'VV'), ('아요', 'EC'), ('창원', 'NNP'), ('드', 'NNP'), ('러그', 'NNP'), ('대', 'VV'), ('업', 'VV')]
# 31500  [('오방', 'NNP'), ('약국', 'NNP'), ('텔레그램', 'NNP'), ('pinkman', 'SL'), ('114', 'NNP'), ('전라도', 'NNP'), ('아이스 밀크', 'NNP'), ('케타민', 'NNP'), ('도매', 'NNP'), ('강동', 'NNP'), ('합성', 'NNG'), ('대마초', 'NNP'), ('강남', 'NNP'), ('허브', 'NNP'), ('액상', 'NNG'), ('창원', 'NNP'), ('엑시', 'NNG'), ('터', 'NNB'), ('시', 'NNB'), ('아이스', 'NNP'), ('뽕', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('법', 'NNB'), ('코카인', 'NNP')]
# 31501  [('국가대표', 'NNP'), ('coreaice', 'SL'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('코카인', 'NNP'), ('판매처', 'NNG'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('작대기', 'NNG'), ('주사', 'NNP'), ('아이스', 'NNP'), ('뽕', 'NNG'), ('케타민', 'NNP'), ('아이스', 'NNP'), ('1', 'SN'), ('G', 'SL'), ('사', 'NNG'), ('끼', 'NNG'), ('엑스터시', 'NNP'), ('떨', 'VV'), ('사', 'EC'), ('는', 'JX'), ('곳', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('가격', 'NNP'), ('떨', 'VV'), ('파', 'VV'), ('ㅂ니다', 'EC'), ('케타민', 'NNP'), ('작대기', 'NNG'), ('술', 'NNG'), ('서울', 'NNP'), ('아이스', 'NNP'), ('빙', 'MAG'), ('두', 'JX'), ('필', 'NNP'), ('로', 'JKB'), ('폰', 'NNG'), ('팔', 'VV'), ('는', 'ETM'), ('곳', 'NNG'), ('사티', 'NNP'), ('바', 'NNB'), ('캔디', 'NNP'), ('판매처', 'NNG'), ('케타민', 'NNP'), ('아이스', 'NNP'), ('술', 'NNG'), ('인증', 'NNP'), ('딜러', 'NNP')]
# 31502  [('텔레그램', 'NNP'), ('JRice', 'SL'), ('1', 'SN'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('무한', 'NNP'), ('히로뽕', 'NNG'), ('파', 'VV'), ('ㅂ니다', 'EC'), ('반', 'XPN'), ('작대기', 'NNG'), ('사', 'NNG'), ('끼', 'NNG'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('케타민', 'NNP'), ('엘', 'NNP'), ('에디', 'NNP'), ('클럽', 'NNP'), ('파티', 'NNP'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('후기', 'NNG'), ('떨', 'VV'), ('팔', 'VV'), ('는', 'ETM'), ('곳', 'NNG'), ('엑시', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETM'), ('가격', 'NNP'), ('차갑', 'VA'), ('ㄴ', 'ETM'), ('수', 'NNB'), ('ㄹ', 'JKO'), ('아이스', 'NNP'), ('얼음', 'NNP'), ('주사', 'NNP'), ('사용', 'NNG'), ('방법', 'NNG'), ('아이스', 'NNP'), ('뽕', 'NNG'), ('술', 'NNG'), ('구매', 'NNG'), ('담배', 'NNG'), ('마약', 'NNP'), ('효과', 'NNG'), ('강남', 'NNP'), ('파티', 'NNP'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('코카인', 'NNP')]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           hannanum  \
# 0      [('카카오톡', 'N'), ('EHKT', 'F'), ('15', 'N'), ('빻', 'P'), ('은', 'E'), ('깨떨', 'N'), ('먹', 'P'), ('고', 'E'), ('3시', 'N'), ('넘', 'P'), ('어서', 'E'), ('작대기', 'N'), ('소스', 'N'), ('를', 'J'), ('만들', 'P'), ('었는데', 'E'), ('발정제', 'N'), ('후추', 'N'), ('를', 'J'), ('더', 'M'), ('넣', 'P'), ('어', 'E'), ('주', 'P'), ('면', 'E'), ('구입', 'N'), ('김치', 'N'), ('겉잎', 'N'), ('으로', 'J'), ('꽁치', 'N'), ('한토막', 'N'), ('을', 'J'), ('구매', 'N'), ('오리', 'N'), ('는', 'J'), ('와인숙성훈제오리', 'N'), ('이', 'J'), ('더라고', 'E'), ('요', 'J'), ('대마초', 'N'), ('하', 'P'), ('ㄴ', 'E'), ('식', 'N'), ('이탈리아', 'N'), ('스페', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('태국', 'N'), ('요리', 'N'), ('의', 'J'), ('캔디', 'N'), ('가능', 'N'), ('하', 'X'), ('다니', 'E'), ('실화', 'N'), ('이', 'J'), ('ㄴ가', 'E'), ('요', 'J'), ('대마', 'N')]
# 1      [('카카오톡', 'N'), ('EHKT', 'F'), ('살', 'P'), ('아', 'E'), ('오', 'P'), ('ㄴ', 'E'), ('나', 'N'), ('의', 'J'), ('노력', 'N'), ('이', 'J'), ('떨', 'P'), ('ㄹ', 'E'), ('정확한', 'N'), ('재료', 'N'), ('의', 'J'), ('작대기', 'N'), ('완벽', 'N'), ('하', 'X'), ('게', 'E'), ('적응', 'N'), ('이', 'J'), ('발정제', 'N'), ('넣', 'P'), ('고', 'E'), ('골고루', 'M'), ('아이스', 'N'), ('한국', 'N'), ('야쿠르트', 'N'), ('하이프레시', 'N'), ('밀키트', 'N'), ('작대기', 'N'), ('두부김치해야겠어요', 'N'), ("'", 'S'), ('대마초', 'N'), ('캔디', 'N'), ('여유', 'N'), ('롭', 'X'), ('게', 'E'), ('만들', 'P'), ('어', 'E'), ('보', 'P'), ('세', 'E'), ('요', 'J'), ('대마', 'N')]
# 2      [('여성', 'N'), ('최음제', 'N'), ('판매', 'N'), ('씨엘팜', 'N'), ('비닉스', 'N'), ('필름', 'N'), ('구입', 'N'), ('사이트', 'N'), (':', 'S')]
# 3      [('이슈', 'N'), ('맛집', 'N'), ('정보', 'N'), ('피디수첩', 'N'), ('클럽', 'N'), ('유흥업소', 'N'), ('범죄', 'N'), ('에', 'J'), ('사용', 'N'), ('되', 'X'), ('ㄴ', 'E'), ('마약', 'N'), ('GHB', 'F'), ('물뽕', 'N'), ('체내', 'N'), ('검출', 'N'), ('되', 'P'), ('지', 'E'), ('않', 'P'), ('는', 'E'), ('성분', 'N'), ('오늘방송', 'N'), ('다시보', 'N'), ('이', 'J'), ('기', 'E')]
# 4      [('김학', 'N'), ('의', 'J'), ('국민의당', 'N'), ('특수강간범', 'N'), ('물뽕', 'N'), ('마약', 'N'), ('박근혜', 'N'), ('정부', 'N'), ('법무부차관', 'N'), ('검사출신', 'N')]
# ...                                                                                                                                             ...
# 31498  [('국가대표', 'N'), ('coreaice', 'F'), ('아이스작대기', 'N'), ('코카', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('작대기사용법', 'N'), ('아이스얼음주사', 'N'), ('인천아이스', 'N'), ('허브', 'N'), ('케이', 'N'), ('아이스드랍', 'N'), ('아이스작대기', 'N'), ('클럽약', 'N'), ('사탕', 'N'), ('떨파는곳', 'N'), ('엑스터시', 'N'), ('떨판매', 'N'), ('작대기', 'N'), ('빙두', 'N'), ('천안아이스', 'N'), ('떨가격', 'N'), ('서울아이스', 'N'), ('떨판매', 'N'), ('아이스술', 'N'), ('아이스사는곳', 'N')]
# 31499  [('오방약국', 'N'), ('텔레그램', 'N'), ('pinkman', 'F'), ('114', 'N'), ('경남드라퍼모집', 'N'), ('코카인팝니다', 'N'), ('파티마약하는법', 'N'), ('케이팔아요', 'N'), ('정글주스팔아요', 'N'), ('창원드러그', 'N'), ('댑', 'N')]
# 31500  [('오방약국', 'N'), ('텔레그램', 'N'), ('pinkman', 'F'), ('114', 'N'), ('전라도아이스', 'N'), ('밀크케타민도매', 'N'), ('강동합성대마초', 'N'), ('강남허브액상', 'N'), ('창원엑시터시', 'N'), ('아이스뽕하는법', 'N'), ('코카인', 'N')]
# 31501  [('국가대표', 'N'), ('coreaice', 'F'), ('아이스작대기', 'N'), ('코카', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('판매처', 'N'), ('아이스작대기', 'N'), ('작대기주사', 'N'), ('아이스뽕', 'N'), ('케타민', 'N'), ('아이스1G', 'N'), ('사끼', 'N'), ('엑스터시', 'N'), ('떨사는곳', 'N'), ('떨가격', 'N'), ('떨팝니다', 'N'), ('케타민', 'N'), ('작대기술', 'N'), ('서울아이스', 'N'), ('빙두', 'N'), ('필로폰파는곳', 'N'), ('사티바', 'N'), ('캔디판매처', 'N'), ('케타민', 'N'), ('아이스술', 'N'), ('인증딜러', 'N')]
# 31502  [('텔레그램', 'N'), ('JRice1', 'N'), ('아이스작대기', 'N'), ('무한', 'N'), ('히로뽕', 'N'), ('팔', 'P'), ('ㅂ니다', 'E'), ('반작대', 'N'), ('이', 'J'), ('기', 'E'), ('사끼', 'N'), ('아이스작대기', 'N'), ('케타민', 'N'), ('엘', 'N'), ('에이', 'J'), ('디', 'E'), ('클럽파티', 'N'), ('떨후', 'N'), ('이', 'J'), ('기', 'E'), ('떨파는곳', 'N'), ('엑시', 'N'), ('떨가격', 'N'), ('차갑', 'P'), ('은', 'E'), ('술', 'N'), ('아이스얼음주사사용방법', 'N'), ('아이스뽕', 'N'), ('술구매', 'N'), ('담배', 'N'), ('마약효과', 'N'), ('강남파티', 'N'), ('아이스작대기', 'N'), ('코카인', 'N')]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  kkma  \
# 0      [('카카오', 'NNG'), ('톡', 'MAG'), ('EHKT', 'OL'), ('15', 'NR'), ('빻', 'VV'), ('은', 'ETD'), ('깨', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('먹', 'VV'), ('고', 'ECE'), ('3', 'NR'), ('시', 'NNM'), ('넘', 'VV'), ('어서', 'ECD'), ('작대기', 'NNG'), ('소스', 'NNG'), ('를', 'JKO'), ('만들', 'VV'), ('었', 'EPT'), ('는데', 'ECD'), ('발', 'NNG'), ('정제', 'NNG'), ('후추', 'NNG'), ('를', 'JKO'), ('더', 'MAG'), ('넣', 'VV'), ('어', 'ECD'), ('주', 'VXV'), ('면', 'ECE'), ('구입', 'NNG'), ('김치', 'NNG'), ('겉잎', 'NNG'), ('으로', 'JKM'), ('꽁치', 'NNG'), ('한', 'MDN'), ('토막', 'NNG'), ('을', 'JKO'), ('구매', 'NNG'), ('오리', 'NNG'), ('는', 'JX'), ('와인', 'NNG'), ('숙성', 'NNG'), ('훈제', 'NNG'), ('오', 'NNG'), ('리더', 'NNG'), ('라고', 'JX'), ('요', 'JX'), ('대마초', 'NNG'), ('한식', 'NNG'), ('이탈리아', 'NNP'), ('스페인', 'NNG'), ('태국', 'NNG'), ('요리', 'NNG'), ('의', 'JKG'), ('캔디', 'NNG'), ('가능', 'NNG'), ('하', 'XSV'), ('다니', 'EFN'), ('시', 'VV'), ('ㄹ', 'ETD'), ('화인', 'NNG'), ('가요', 'NNG'), ('대마', 'NNG')]
# 1      [('카카오', 'NNG'), ('톡', 'MAG'), ('EHKT', 'OL'), ('살아오', 'VV'), ('ㄴ', 'ETD'), ('나의', 'NNG'), ('노력', 'NNG'), ('이', 'JKS'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('정확', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('재료', 'NNG'), ('의', 'JKG'), ('작대기', 'NNG'), ('완벽', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('적응', 'NNG'), ('이', 'JKS'), ('발정', 'NNG'), ('제', 'XSN'), ('넣', 'VV'), ('고', 'ECE'), ('골고루', 'MAG'), ('아이스', 'NNG'), ('한국', 'NNG'), ('야', 'NNG'), ('쿠르트', 'UN'), ('하이', 'NNG'), ('프', 'UN'), ('레', 'NNG'), ('시', 'NNG'), ('밀', 'NNG'), ('키트', 'NNG'), ('작대기', 'NNG'), ('두부', 'NNG'), ('김치해야겠어', 'UN'), ('요', 'JX'), ("'", 'SS'), ('대마초', 'NNG'), ('캔디', 'NNG'), ('여유', 'NNG'), ('롭', 'XSA'), ('게', 'ECD'), ('만들', 'VV'), ('어', 'ECD'), ('보세', 'NNG'), ('요', 'JX'), ('대마', 'NNG')]
# 2      [('여성', 'NNG'), ('최음제', 'NNG'), ('판매', 'NNG'), ('씨', 'NNG'), ('엘', 'NNG'), ('파', 'VV'), ('ㅁ', 'ETN'), ('비', 'NNG'), ('닉스', 'NNP'), ('필름', 'NNG'), ('구입', 'NNG'), ('사이트', 'NNG'), (':', 'SP')]
# 3      [('이슈', 'NNG'), ('맛', 'NNG'), ('집', 'NNG'), ('정보', 'NNG'), ('피디', 'NNG'), ('수첩', 'NNG'), ('클럽', 'NNG'), ('유흥업소', 'NNG'), ('범죄', 'NNG'), ('에', 'JKM'), ('사용', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('마약', 'NNG'), ('GHB', 'OL'), ('물뽕', 'NNG'), ('체내', 'NNG'), ('검출', 'NNG'), ('되', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('는', 'ETD'), ('성분', 'NNG'), ('오늘', 'NNG'), ('방송', 'NNG'), ('다시', 'MAG'), ('보', 'VV'), ('기', 'ETN')]
# ...
# ...                                                                                                                                                                                                                                                           ...
# 31498  [('국가', 'NNG'), ('대표', 'NNG'), ('coreaice', 'OL'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNP'), ('작대기', 'NNG'), ('사용법', 'NNG'), ('아이스', 'NNG'), ('얼음', 'NNG'), ('주사', 'NNG'), ('인천', 'NNG'), ('아이스', 'NNG'), ('허브', 'NNG'), ('케이', 'NNG'), ('아이스', 'NNG'), ('드랍', 'UN'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('클럽', 'NNG'), ('약', 'NNG'), ('사탕', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('파', 'NNG'), ('는', 'JX'), ('곳', 'NNG'), ('엑스터시', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('판매', 'NNG'), ('작대기', 'NNG'), ('빙', 'MAG'), ('두', 'MDN'), ('천안', 'NNG'), ('아이스', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('가격', 'NNG'), ('서울', 'NNG'), ('아이스', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('판매', 'NNG'), ('아이스', 'NNG'), ('술', 'NNG'), ('아이스', 'NNG'), ('사', 'VV'), ('는', 'ETD'), ('곳', 'NNG')]
# 31499  [('오방', 'NNG'), ('약국', 'NNG'), ('텔', 'UN'), ('레', 'NNG'), ('그램', 'NNM'), ('pinkman', 'OL'), ('114', 'NR'), ('경남', 'NNP'), ('드', 'VV'), ('라', 'ECD'), ('푸', 'VV'), ('어', 'ECS'), ('모집', 'NNG'), ('코카인', 'NNP'), ('팝', 'NNG'), ('니', 'VV'), ('다', 'ECS'), ('파티', 'NNG'), ('마약', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('법', 'NNG'), ('케이', 'NNG'), ('팔', 'VV'), ('아요', 'EFN'), ('정글', 'NNG'), ('주스', 'NNG'), ('팔', 'VV'), ('아요', 'EFN'), ('창원', 'NNG'), ('드러그', 'NNG'), ('대', 'VV')]
# 31500  [('오방', 'NNG'), ('약국', 'NNG'), ('텔', 'UN'), ('레', 'NNG'), ('그램', 'NNM'), ('pinkman', 'OL'), ('114', 'NR'), ('전라도', 'NNG'), ('아이스', 'NNG'), ('밀크', 'NNG'), ('케타민', 'NNG'), ('도', 'JX'), ('매', 'NNG'), ('강동', 'NNP'), ('합성', 'NNG'), ('대마초', 'NNG'), ('강남', 'NNG'), ('허브', 'NNG'), ('액상', 'NNG'), ('창원', 'NNG'), ('엑', 'UN'), ('시', 'NNG'), ('트', 'VV'), ('어', 'ECS'), ('시', 'NNG'), ('아이스', 'NNG'), ('뽕', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('법', 'NNG'), ('코카인', 'NNP')]
# 31501  [('국가', 'NNG'), ('대표', 'NNG'), ('coreaice', 'OL'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNP'), ('판매처', 'NNG'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('작대기', 'NNG'), ('주사', 'NNG'), ('아이스', 'NNG'), ('뽕', 'NNG'), ('케타민', 'NNG'), ('아이스', 'NNG'), ('1', 'NR'), ('G', 'OL'), ('사', 'VV'), ('아', 'ECS'), ('끼', 'NNG'), ('엑스터시', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('살', 'VV'), ('는', 'ETD'), ('곳', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('가격', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('팝', 'NNG'), ('니', 'VV'), ('다', 'ECS'), ('케타민', 'NNG'), ('작대기', 'NNG'), ('술', 'XSN'), ('서울', 'NNG'), ('아이스', 'NNG'), ('빙', 'MAG'), ('두', 'MDN'), ('필로폰', 'NNG'), ('팔', 'VV'), ('는', 'ETD'), ('곳', 'NNG'), ('사', 'NNG'), ('티', 'NNG'), ('바', 'NNG'), ('캔디', 'NNG'), ('판매처', 'NNG'), ('케타민', 'NNG'), ('아이스', 'NNG'), ('술', 'NNG'), ('인증', 'NNG'), ('딜러', 'NNG')]
# 31502  [('텔', 'UN'), ('레', 'NNG'), ('그램', 'NNM'), ('JRice', 'OL'), ('1', 'NR'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('무한', 'NNG'), ('히로뽕', 'NNG'), ('팔', 'VV'), ('ㅂ니다', 'EFN'), ('반', 'NNG'), ('작대기', 'NNG'), ('사', 'NNG'), ('끼', 'NNG'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('케타민', 'NNG'), ('엘', 'NNG'), ('에', 'JKM'), ('디', 'NNG'), ('클럽', 'NNG'), ('파티', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('후기', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('파', 'NNG'), ('는', 'JX'), ('곳', 'NNG'), ('엑', 'UN'), ('시', 'NNG'), ('떨', 'VV'), ('ㄹ', 'ETD'), ('가격', 'NNG'), ('차갑', 'VA'), ('ㄴ', 'ETD'), ('술', 'NNG'), ('아이스', 'NNG'), ('얼음', 'NNG'), ('주사', 'NNG'), ('사용', 'NNG'), ('방법', 'NNG'), ('아이스', 'NNG'), ('뽕', 'NNG'), ('술', 'NNG'), ('구매', 'NNG'), ('담배', 'NNG'), ('마약', 'NNG'), ('효과', 'NNG'), ('강남', 'NNG'), ('파티', 'NNG'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNP')]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               mecab
# 0      [('카카오톡', 'NNP'), ('EHKT', 'SL'), ('15', 'SN'), ('빻', 'VV'), ('은', 'ETM'), ('깨', 'NNG'), ('떨', 'XSN'), ('먹', 'VV'), ('고', 'EC'), ('3', 'SN'), ('시', 'NNBC'), ('넘', 'VV'), ('어서', 'EC'), ('작대기', 'NNG'), ('소스', 'NNG'), ('를', 'JKO'), ('만들', 'VV'), ('었', 'EP'), ('는데', 'EC'), ('발정', 'NNG'), ('제', 'XSN'), ('후추', 'NNG'), ('를', 'JKO'), ('더', 'MAG'), ('넣', 'VV'), ('어', 'EC'), ('주', 'VX'), ('면', 'EC'), ('구입', 'NNG'), ('김치', 'NNG'), ('겉잎', 'NNG'), ('으로', 'JKB'), ('꽁치', 'NNG'), ('한', 'MM'), ('토막', 'NNBC'), ('을', 'JKO'), ('구매', 'NNG'), ('오리', 'NNG'), ('는', 'JX'), ('와인', 'NNG'), ('숙성', 'NNG'), ('훈제', 'NNG'), ('오리', 'VV'), ('더라고요', 'EC'), ('대마초', 'NNG'), ('한식', 'NNG'), ('이탈리아', 'NNP'), ('스페인', 'NNP'), ('태국', 'NNP'), ('요리', 'NNG'), ('의', 'JKG'), ('캔디', 'NNG'), ('가능', 'NNG'), ('하', 'XSA'), ('다니', 'EC'), ('실화', 'NNG'), ('인가요', 'VCP+EC'), ('대마', 'NNG')]
# 1      [('카카오톡', 'NNP'), ('EHKT', 'SL'), ('살아온', 'VV+ETM'), ('나', 'NP'), ('의', 'JKG'), ('노력', 'NNG'), ('이', 'JKS'), ('떨', 'VV+ETM'), ('정확', 'NNG'), ('한', 'XSA+ETM'), ('재료', 'NNG'), ('의', 'JKG'), ('작대기', 'NNG'), ('완벽', 'NNG'), ('하', 'XSA'), ('게', 'EC'), ('적응', 'NNG'), ('이', 'JKS'), ('발정', 'NNG'), ('제', 'XSN'), ('넣', 'VV'), ('고', 'EC'), ('골고루', 'MAG'), ('아이스', 'NNG'), ('한국', 'NNP'), ('야쿠르트', 'NNP'), ('하이프', 'NNP'), ('레시', 'NNP'), ('밀', 'NNP'), ('키트', 'NNP'), ('작대기', 'NNG'), ('두부', 'NNG'), ('김치', 'NNG'), ('해야', 'XSV+EC+VX'), ('겠', 'EP'), ('어요', 'EF'), ("'", 'SY'), ('대마초', 'NNG'), ('캔디', 'NNG'), ('여유', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('만들', 'VV'), ('어', 'EC'), ('보', 'VX'), ('세요', 'EP+EF'), ('대마', 'NNG')]
# 2      [('여성', 'NNG'), ('최음제', 'NNG'), ('판매', 'NNG'), ('씨엘', 'NNP'), ('팜', 'NNP'), ('비', 'XPN'), ('닉스', 'NNG'), ('필름', 'NNG'), ('구입', 'NNG'), ('사이트', 'NNG'), (':', 'SC')]
# 3      [('이슈', 'NNG'), ('맛집', 'NNG'), ('정보', 'NNG'), ('피디', 'NNG'), ('수첩', 'NNG'), ('클럽', 'NNG'), ('유흥업소', 'NNG'), ('범죄', 'NNG'), ('에', 'JKB'), ('사용', 'NNG'), ('된', 'XSV+ETM'), ('마약', 'NNG'), ('GHB', 'SL'), ('물뽕', 'NNG'), ('체내', 'NNG'), ('검출', 'NNG'), ('되', 'VV'), ('지', 'EC'), ('않', 'VX'), ('는', 'ETM'), ('성분', 'NNG'), ('오늘', 'NNG'), ('방송', 'NNG'), ('다시', 'MAG'), ('보', 'VV'), ('기', 'ETN')]
# 4      [('김학', 'NNP'), ('의', 'JKG'), ('국민', 'NNG'), ('의', 'JKG'), ('당', 'NNG'), ('특수', 'NNG'), ('강간범', 'NNG'), ('물뽕', 'NNG'), ('마약', 'NNG'), ('박근혜', 'NNP'), ('정부', 'NNG'), ('법무부', 'NNG'), ('차관', 'NNG'), ('검사', 'NNG'), ('출신', 'NNG')]
# ...                                                                                                                                                                                                                                  ...
# 31498  [('국가', 'NNG'), ('대표', 'NNG'), ('coreaice', 'SL'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNG'), ('작대기', 'NNG'), ('사용법', 'NNG'), ('아이스', 'NNG'), ('얼음', 'NNG'), ('주사', 'NNG'), ('인천', 'NNP'), ('아이스', 'NNG'), ('허브', 'NNG'), ('케이', 'NNG'), ('아이스', 'NNP'), ('드', 'NNP'), ('랍', 'NNP'), ('아이스', 'NNP'), ('작대기', 'NNG'), ('클럽', 'NNG'), ('약', 'NNG'), ('사탕', 'NNG'), ('떨', 'MAG'), ('파', 'VV'), ('는', 'ETM'), ('곳', 'NNG'), ('엑스터시', 'NNG'), ('떨', 'VV+ETM'), ('판매', 'NNG'), ('작대기', 'NNG'), ('빙', 'NNG'), ('두', 'JX'), ('천안', 'NNP'), ('아이스', 'NNG'), ('떨', 'VV+ETM'), ('가격', 'NNG'), ('서울', 'NNP'), ('아이스', 'NNG'), ('떨', 'VV+ETM'), ('판매', 'NNG'), ('아이스', 'NNG'), ('술', 'NNG'), ('아이스', 'NNG'), ('사', 'VV'), ('는', 'ETM'), ('곳', 'NNG')]
# 31499  [('오방', 'NNG'), ('약국', 'NNG'), ('텔레', 'NNP'), ('그램', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('경남', 'NNP'), ('드라퍼', 'NNP'), ('모집', 'NNG'), ('코카인', 'NNG'), ('팝', 'NNG'), ('니', 'JC'), ('다', 'MAG'), ('파티', 'NNG'), ('마약', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('법', 'NNG'), ('케이', 'NNG'), ('팔', 'VV'), ('아요', 'EF'), ('정글', 'NNG'), ('주스', 'NNG'), ('팔', 'VV'), ('아요', 'EF'), ('창원', 'NNP'), ('드러그', 'NNG'), ('댑', 'UNKNOWN')]
# 31500  [('오방', 'NNG'), ('약국', 'NNG'), ('텔레', 'NNP'), ('그램', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('전라도', 'NNP'), ('아이스', 'NNP'), ('밀크', 'NNP'), ('케타민', 'NNG'), ('도매', 'NNG'), ('강', 'NNG'), ('동합', 'NNG'), ('성', 'XSN'), ('대마초', 'NNG'), ('강남', 'NNP'), ('허브', 'NNP'), ('액상', 'NNG'), ('창원', 'NNP'), ('엑', 'NNP'), ('시터', 'NNP'), ('시', 'NNG'), ('아이스', 'NNG'), ('뽕', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('법', 'NNG'), ('코카인', 'NNG')]
# 31501  [('국가', 'NNG'), ('대표', 'NNG'), ('coreaice', 'SL'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNG'), ('판매처', 'NNG'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('작대기', 'NNG'), ('주사', 'NNG'), ('아이스', 'NNG'), ('뽕', 'MAG'), ('케타민', 'NNG'), ('아이스', 'NNG'), ('1', 'SN'), ('G', 'SL'), ('사', 'NR'), ('끼', 'NNBC'), ('엑스터시', 'NNG'), ('떨', 'MAG'), ('사', 'VV'), ('는', 'ETM'), ('곳', 'NNB'), ('떨', 'VV+ETM'), ('가격', 'NNG'), ('떨', 'VV+ETM'), ('팝', 'NNG'), ('니', 'JC'), ('다', 'MAG'), ('케타민', 'NNG'), ('작대', 'NNG'), ('기술', 'NNG'), ('서울', 'NNP'), ('아이스', 'NNG'), ('빙', 'MAG'), ('두', 'MM'), ('필로폰', 'NNG'), ('파', 'VV'), ('는', 'ETM'), ('곳', 'NNG'), ('사티', 'NNP'), ('바', 'NNP'), ('캔디', 'NNG'), ('판매처', 'NNG'), ('케타민', 'NNG'), ('아이스', 'NNG'), ('술', 'NNG'), ('인증', 'NNG'), ('딜러', 'NNG')]
# 31502  [('텔레', 'NNP'), ('그램', 'NNG'), ('JRice', 'SL'), ('1', 'SN'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('무한', 'NNG'), ('히로뽕', 'NNG'), ('팝', 'NNG'), ('니다', 'VCP+EF'), ('반작', 'MAG'), ('대기', 'NNG'), ('사', 'NR'), ('끼', 'NNBC'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('케타민', 'NNG'), ('엘', 'NNG'), ('에', 'JKB'), ('디', 'NNG'), ('클럽', 'NNG'), ('파티', 'NNG'), ('떨', 'VV+ETM'), ('후기', 'NNG'), ('떨', 'MAG'), ('파', 'VV'), ('는', 'ETM'), ('곳', 'NNB'), ('엑', 'IC'), ('시', 'NNG'), ('떨', 'VV+ETM'), ('가격', 'NNG'), ('차가운', 'VA+ETM'), ('술', 'NNG'), ('아이스', 'NNG'), ('얼음', 'NNG'), ('주사', 'NNG'), ('사용', 'NNG'), ('방법', 'NNG'), ('아이스', 'NNG'), ('뽕', 'MAG'), ('술', 'NNG'), ('구매', 'NNG'), ('담배', 'NNG'), ('마약', 'NNG'), ('효과', 'NNG'), ('강남', 'NNP'), ('파티', 'NNG'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('코카인', 'NNG')]
#
# [31503 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31503 entries, 0 to 31502
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type1             31503 non-null  object
#  1   type2             31503 non-null  object
#  2   date              31503 non-null  object
#  3   id                31503 non-null  float64
#  4   user.username     31503 non-null  object
#  5   user.displayname  31494 non-null  object
#  6   place             4 non-null      object
#  7   user.location     3983 non-null   object
#  8   content           31503 non-null  object
#  9   likeCount         31502 non-null  float64
#  10  retweetCount      31502 non-null  float64
#  11  viewCount         17989 non-null  float64
#  12  hashtags          28696 non-null  object
#  13  media             27119 non-null  object
#  14  sourceLabel       31502 non-null  object
#  15  okt               31503 non-null  object
#  16  komoran           31503 non-null  object
#  17  hannanum          31503 non-null  object
#  18  kkma              31503 non-null  object
#  19  mecab             31503 non-null  object
# dtypes: float64(4), object(16)
# memory usage: 4.8+ MB

# %%
df = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/tokenizing/total_tokenized_mecab.csv")
df
# Out:
# /var/folders/yn/4yp008q55jv19mts19hw5lzc0000gn/T/ipykernel_14116/756327402.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/yujinkim/Desktop/workspace/DScap/twitterdata/tokenizing/total_tokenized_mecab.csv")
#                 type1   type2                       date            id  \
# 0      사일로시빈           환각버섯    2021-01-09 01:12:15+00:00  1.347710e+18
# 1      아편              신의눈물    2021-01-09 02:18:36+00:00  1.347730e+18
# 2      사일로시빈           환각버섯    2021-01-09 11:02:58+00:00  1.347860e+18
# 3      코카인             지역명코카인  2021-01-14 13:26:25+00:00  1.349710e+18
# 4      아편              신의눈물    2021-01-21 16:20:07+00:00  1.352290e+18
# ...    ..               ...                          ...           ...
# 40965  메스암페타민  아이스  2023.3.9 20:02             1.633790e+18
# 40966  GHB             물뽕      2023.3.9 20:43             1.633800e+18
# 40967  메스암페타민  찬술  2023.3.9 21:17             1.633800e+18
# 40968  메스암페타민  작대기     2023.3.9 21:17             1.633800e+18
# 40969  메스암페타민  아이스  2023.3.9 23:48             1.633840e+18
#
#          user.username   user.displayname place user.location  \
# 0      TiaWelch16       텔레 gbl42           NaN   NaN
# 1      Mariana47241037  텔레그램 candys1004    NaN   NaN
# 2      Prudenc06014752  텔레 bingre          NaN   NaN
# 3      n9oJ2Olm2NYVz0T  오승미                NaN   NaN
# 4      MeganHouchens2   텔레그램 tkwk21        NaN   NaN
# ...               ...           ...        ...   ...
# 40965  fridoendra       fridolin mahendra  NaN   semarang
# 40966  irhul_aregz      irhul              NaN   NaN
# 40967  shalfarezkiana   shalfa rezkiana    NaN   NaN
# 40968  shalfarezkiana   shalfa rezkiana    NaN   NaN
# 40969  fridoendra       fridolin mahendra  NaN   semarang
#
#                                                                                                             content  \
# 0      레드불 weed 레딧입고 아이스복용 환각버섯류팔아요 매스암페타민 바르비탈구매처 카마그라인증 정확하게 확인 하시고 거래해 주세요
# 1      신의눈물 사끼 레드불 엘 차가운술소량입고 엑스터시구입 캐너비스 위드정품 지방권도 가능
# 2      환각버섯 캐너비스 스컬 네토 바르비탈 버드구입방법 몰리 히로뽕 캔디팝니다 트위터 제 프로필 소개에 채널링크 있어요
# 3      강남 오프만남 변녀 발정 얼음구입방법 오프 코카인팔아요 만남알바 허브가격 오프녀 폰섹 캐너비스 고기입고 자위 긴밤 벤조디아제핀구해요아이스작대기팝니다 영섹 라이트 아이스복용법 prefer72361
# 4      문아이스 문의주세요 고급북술 확보 액상떨구입처 케타민 찬술 신의눈물 디엠티 캔디구매 고기정품 암페타민
# ...                                                         ...
# 40965  신의눈물 텔레그램 채널 pinkman114 0 수원콕 대구케미컬약 대전마약 고퀄아이스구입 드러그 디스펜서리
# 40966  인천케타민밀크 텔레그램 채널 pinkman114 0 용인하선모집 경북보안좌표 전남프로포폴 경남하이드로몰핀 수원인슐린 물뽕
# 40967  케미컬약팔아요 텔레그램 채널 pinkman114 0 차가운술사는법 충남펜타닐 광주작대기술 케이구매방법 펜타닐상선 찬술
# 40968  케미컬약팔아요 텔레그램 채널 pinkman114 0 차가운술사는법 충남펜타닐 광주작대기술 케이구매방법 펜타닐상선 찬술
# 40969  원석케이후기 텔레그램 채널 pinkman114 0 부산포도허브 콕구입하는방법 아이스뽕구매처 충남인증업자 포도허브구하는법 아이스뽕사는법
#
#        likeCount  retweetCount  viewCount                          hashtags  \
# 0      0          0            NaN         NaN
# 1      0          0            NaN         NaN
# 2      0          0            NaN         ['버드구입방법', '몰리', '히로뽕', '캔디팝니다']
# 3      0          0            NaN         NaN
# 4      0          0            NaN         NaN
# ...   ..         ..             ..         ...
# 40965  0          0             79.0       ['신의눈물']
# 40966  0          0             236.0      ['인천케타민밀크']
# 40967  0          0             93.0       ['케미컬약팔아요']
# 40968  0          0             93.0       ['케미컬약팔아요']
# 40969  0          0             37.0       ['원석케이후기']
#
#                                                                                                                                                                                    media  \
# 0      [Photo(previewUrl='https://pbs.twimg.com/media/ErQJl8eUYAEy4o3?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/ErQJl8eUYAEy4o3?format=jpg&name=orig', altText=None)]
# 1      [Photo(previewUrl='https://pbs.twimg.com/media/ErQYx1JUcAAnH7c?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/ErQYx1JUcAAnH7c?format=jpg&name=orig', altText=None)]
# 2      NaN
# 3      [Photo(previewUrl='https://pbs.twimg.com/media/ErshmK3VQAEwpwB?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/ErshmK3VQAEwpwB?format=jpg&name=orig', altText=None)]
# 4      NaN
# ...    ...
# 40965  [Photo(previewUrl='https://pbs.twimg.com/media/FqxfEVRaMAIcxui?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FqxfEVRaMAIcxui?format=jpg&name=orig', altText=None)]
# 40966  [Photo(previewUrl='https://pbs.twimg.com/media/Fqxof-uacAEZ9uo?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/Fqxof-uacAEZ9uo?format=jpg&name=orig', altText=None)]
# 40967  [Photo(previewUrl='https://pbs.twimg.com/media/FqxwGqwaQAAAV8S?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FqxwGqwaQAAAV8S?format=jpg&name=orig', altText=None)]
# 40968  [Photo(previewUrl='https://pbs.twimg.com/media/FqxwGqwaQAAAV8S?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FqxwGqwaQAAAV8S?format=jpg&name=orig', altText=None)]
# 40969  [Photo(previewUrl='https://pbs.twimg.com/media/FqySuZJaIAQuSz4?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FqySuZJaIAQuSz4?format=jpg&name=orig', altText=None)]
#
#                sourceLabel  Unnamed: 0  \
# 0      Twitter Web App     NaN
# 1      Twitter Web App     NaN
# 2      Twitter Web App     NaN
# 3      Twitter for Android NaN
# 4      Twitter Web App     NaN
# ...                ...      ..
# 40965  Twitter Web App     NaN
# 40966  Twitter Web App     NaN
# 40967  Twitter Web App     NaN
# 40968  Twitter Web App     NaN
# 40969  Twitter Web App     NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    mecab
# 0      [('레드불', 'NNP'), ('weed', 'SL'), ('레딧', 'NNP'), ('입', 'VV'), ('고', 'EC'), ('아이스', 'NNG'), ('복용', 'NNG'), ('환각', 'NNG'), ('버섯', 'NNG'), ('류', 'XSN'), ('팔', 'VV'), ('아요', 'EF'), ('매스', 'NNG'), ('암페타민', 'NNG'), ('바르비탈', 'NNG'), ('구매처', 'NNG'), ('카마', 'NNG'), ('그라', 'NNP'), ('인증', 'NNG'), ('정확', 'NNG'), ('하', 'XSA'), ('게', 'EC'), ('확인', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('고', 'EC'), ('거래', 'NNG'), ('해', 'XSV+EC'), ('주', 'VX'), ('세요', 'EP+EF')]
# 1      [('신', 'NNG'), ('의', 'JKG'), ('눈물', 'NNG'), ('사', 'NR'), ('끼', 'NNBC'), ('레드불', 'NNP'), ('엘', 'JKB+JKO'), ('차가운', 'VA+ETM'), ('술', 'NNG'), ('소량', 'NNG'), ('입', 'VV'), ('고', 'EC'), ('엑스터시', 'NNG'), ('구입', 'NNG'), ('캐너', 'NNP'), ('비스', 'NNP'), ('위드', 'NNP'), ('정품', 'NNG'), ('지방', 'NNG'), ('권', 'XSN'), ('도', 'JX'), ('가능', 'NNG')]
# 2      [('환각', 'NNG'), ('버섯', 'NNG'), ('캐너', 'NNP'), ('비스', 'NNP'), ('스컬', 'NNP'), ('네토', 'NNP'), ('바르비탈', 'NNG'), ('버드', 'NNP'), ('구입', 'NNG'), ('방법', 'NNG'), ('몰리', 'NNG'), ('히로뽕', 'NNG'), ('캔디', 'NNG'), ('팝', 'NNG'), ('니다', 'NNP'), ('트위터', 'NNP'), ('제', 'XPN'), ('프로필', 'NNG'), ('소개', 'NNG'), ('에', 'JKB'), ('채널', 'NNG'), ('링크', 'NNG'), ('있', 'VA'), ('어요', 'EF')]
# 3      [('강남', 'NNP'), ('오프', 'NNG'), ('만남', 'NNG'), ('변', 'XSN'), ('녀', 'NNG'), ('발정', 'NNG'), ('얼음', 'NNG'), ('구입', 'NNG'), ('방법', 'NNG'), ('오프', 'NNG'), ('코카인', 'NNG'), ('팔', 'VV'), ('아요', 'EC'), ('만남', 'NNG'), ('알바', 'NNP'), ('허브', 'NNP'), ('가격', 'NNG'), ('오프', 'NNG'), ('녀', 'NNG'), ('폰', 'NNG'), ('섹', 'NNG'), ('캐너', 'NNP'), ('비스', 'NNP'), ('고기', 'NNG'), ('입', 'VV'), ('고', 'EC'), ('자위', 'NNG'), ('긴', 'VA+ETM'), ('밤', 'NNG'), ('벤조', 'NNG'), ('디아', 'NNG'), ('제', 'XSN'), ('핀', 'NNG'), ('구해요', 'VV+EF'), ('아이스', 'NNG'), ('작대기', 'NNG'), ('팝', 'NNG'), ('니다', 'VCP+EF'), ('영', 'MAG'), ('섹', 'NNP'), ('라이트', 'NNP'), ('아이스', 'NNP'), ('복', 'NNG'), ('용법', 'NNG'), ('prefer', 'SL'), ('72361', 'SN')]
# 4      [('문', 'NNG'), ('아이스', 'NNG'), ('문', 'NNG'), ('의', 'JKG'), ('주세요', 'NNP'), ('고급', 'NNG'), ('북', 'NNP'), ('술', 'NNG'), ('확보', 'NNG'), ('액상', 'NNG'), ('떨', 'VV+ETM'), ('구입', 'NNG'), ('처', 'NNG'), ('케타민', 'NNG'), ('찬술', 'NNG'), ('신', 'NNG'), ('의', 'JKG'), ('눈물', 'NNG'), ('디엠티', 'NNP'), ('캔디', 'NNG'), ('구매', 'NNG'), ('고기', 'NNG'), ('정품', 'NNG'), ('암페타민', 'NNG')]
# ...                                                                                                                                                                                                                                                                                                                                                                         ...
# 40965  [('신', 'NNG'), ('의', 'JKG'), ('눈물', 'NNG'), ('텔레', 'NNP'), ('그램', 'NNG'), ('채널', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('0', 'SN'), ('수원', 'NNP'), ('콕', 'MAG'), ('대구', 'NNP'), ('케미컬', 'NNG'), ('약', 'NNG'), ('대전', 'NNG'), ('마약', 'NNG'), ('고퀄', 'NNG'), ('아이스', 'NNG'), ('구입', 'NNG'), ('드러그', 'NNG'), ('디스', 'NNP'), ('펜', 'NNG'), ('서리', 'NNG')]
# 40966  [('인천', 'NNP'), ('케타민', 'NNG'), ('밀크', 'NNP'), ('텔레', 'NNP'), ('그램', 'NNG'), ('채널', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('0', 'SN'), ('용인', 'NNG'), ('하', 'XSV'), ('선', 'EC+JX'), ('모집', 'NNG'), ('경북', 'NNP'), ('보안', 'NNP'), ('좌표', 'NNG'), ('전남', 'NNP'), ('프로포폴', 'NNP'), ('경남', 'NNP'), ('하이드', 'NNP'), ('로', 'JKB'), ('몰핀', 'NNG'), ('수원', 'NNP'), ('인슐린', 'NNG'), ('물뽕', 'NNG')]
# 40967  [('케미컬', 'NNG'), ('약', 'NNG'), ('팔', 'VV'), ('아요', 'EF'), ('텔레', 'NNP'), ('그램', 'NNG'), ('채널', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('0', 'SN'), ('차가운', 'VA+ETM'), ('술사', 'NNG'), ('는', 'JX'), ('법', 'NNG'), ('충남', 'NNP'), ('펜타닐', 'NNG'), ('광주', 'NNP'), ('작대', 'NNG'), ('기술', 'NNG'), ('케이', 'XSV+EC+JKS'), ('구매', 'NNG'), ('방법', 'NNG'), ('펜타닐', 'NNG'), ('상선', 'NNG'), ('찬술', 'NNG')]
# 40968  [('케미컬', 'NNG'), ('약', 'NNG'), ('팔', 'VV'), ('아요', 'EF'), ('텔레', 'NNP'), ('그램', 'NNG'), ('채널', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('0', 'SN'), ('차가운', 'VA+ETM'), ('술사', 'NNG'), ('는', 'JX'), ('법', 'NNG'), ('충남', 'NNP'), ('펜타닐', 'NNG'), ('광주', 'NNP'), ('작대', 'NNG'), ('기술', 'NNG'), ('케이', 'XSV+EC+JKS'), ('구매', 'NNG'), ('방법', 'NNG'), ('펜타닐', 'NNG'), ('상선', 'NNG'), ('찬술', 'NNG')]
# 40969  [('원석', 'NNG'), ('케이', 'XSV+EC+JKS'), ('후기', 'NNG'), ('텔레', 'NNP'), ('그램', 'NNG'), ('채널', 'NNG'), ('pinkman', 'SL'), ('114', 'SN'), ('0', 'SN'), ('부산포', 'NNG'), ('도', 'JX'), ('허브', 'NNG'), ('콕', 'MAG'), ('구입', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('방법', 'NNG'), ('아이스', 'NNG'), ('뽕', 'MAG'), ('구매처', 'NNG'), ('충남', 'NNP'), ('인증', 'NNG'), ('업자', 'NNG'), ('포도', 'NNG'), ('허브', 'NNG'), ('구하', 'VV'), ('는', 'ETM'), ('법', 'NNG'), ('아이스', 'NNG'), ('뽕', 'MAG'), ('사', 'VV'), ('는', 'ETM'), ('법', 'NNG')]
#
# [40970 rows x 17 columns]

# %% [markdown]
# ## 콘텐츠 길이 분포

# %%
ax = df['content'].str.len().hist()

# plt.rc('font', family='Malgun Gothic')
ax.set_xlabel("content 글자수")
ax.set_ylabel("빈도 수")
# Out:
# Text(0, 0.5, '빈도 수')

# %% [markdown]
# ## 토큰 수 분포

# %%
token = ['okt', 'komoran', 'hannanum', 'kkma']
df['okt'] = df['okt'].apply(lambda x: ast.literal_eval(x))
df['komoran'] = df['komoran'].apply(lambda x: ast.literal_eval(x))
df['hannanum'] = df['hannanum'].apply(lambda x: ast.literal_eval(x))
df['kkma'] = df['kkma'].apply(lambda x: ast.literal_eval(x))
df['mecab'] = df['mecab'].apply(lambda x: ast.literal_eval(x))
df
# Out:
#       type1   type2                       date            id    user.username  \
# 0      GHB   발정제     2021-03-06 14:57:45+00:00  1.368210e+18  gije_cho
# 1      GHB   발정제     2021-03-12 14:39:17+00:00  1.370380e+18  Q54tEl2QSMCVIOI
# 2      GHB   최음제     2022-07-15 06:21:14+00:00  1.547830e+18  H1kUodcLjGk8bjR
# 3      GHB   물뽕      2022-08-08 22:34:46+00:00  1.556770e+18  jkmister11
# 4      GHB   물뽕      2022-08-13 06:12:40+00:00  1.558340e+18  Duckhoo101
# ...    ...   ..                            ...           ...         ...
# 31498  코카인   지역명코카인  2023-03-30 09:03:36+00:00  1.641370e+18  gg8644
# 31499  코카인   지역명코카인  2023-03-30 10:10:34+00:00  1.641380e+18  LMouraIndonesia
# 31500  코카인   지역명코카인  2023-03-30 10:12:03+00:00  1.641380e+18  milnerigbal
# 31501  코카인   지역명코카인  2023-03-30 18:34:46+00:00  1.641510e+18  gg8644
# 31502  코카인   지역명코카인  2023-03-30 18:39:22+00:00  1.641510e+18  hallo226
#
#       user.displayname place user.location  \
# 0      조기제              NaN   대한민국 서울
# 1      성빙               NaN   NaN
# 2      심상봉              NaN   NaN
# 3      Mister           NaN   NaN
# 4      꾸??¹⁴³           NaN   꼬레아
# ...       ...           ...    ...
# 31498  란                NaN   글쎄.
# 31499  Lucas Moura      NaN   NaN
# 31500  Igbal Milner     NaN   NaN
# 31501  란                NaN   글쎄.
# 31502  ヽ(*・ω・)ﾉ         NaN   NaN
#
#                                                                                                                                          content  \
# 0      카카오톡 EHKT 15 빻은 깨떨 먹고 3시 넘어서 작대기 소스를 만들었는데 발정제 후추를 더 넣어주면 구입 김치 겉잎으로 꽁치 한토막을 구매 오리는 와인숙성훈제오리더라고요 대마초 한식 이탈리아 스페인 태국 요리의 캔디 가능하다니 실화인가요 대마
# 1      카카오톡 EHKT 살아온 나의 노력이 떨 정확한 재료의 작대기 완벽하게 적응이 발정제 넣고 골고루 아이스 한국 야쿠르트 하이프레시 밀키트 작대기 두부김치해야겠어요 ' 대마초 캔디 여유롭게 만들어 보세요 대마
# 2      여성 최음제 판매 씨엘팜 비닉스 필름 구입 사이트 :
# 3      이슈 맛집 정보 피디수첩 클럽 유흥업소 범죄에 사용된 마약 GHB 물뽕 체내 검출 되지 않는 성분 오늘방송 다시보기
# 4      김학의 국민의당 특수강간범 물뽕 마약 박근혜 정부 법무부차관 검사출신
# ...                                       ...
# 31498  국가대표 coreaice 아이스작대기 코카인 작대기사용법 아이스얼음주사 인천아이스 허브 케이 아이스드랍 아이스작대기 클럽약 사탕 떨파는곳 엑스터시 떨판매 작대기 빙두 천안아이스 떨가격 서울아이스 떨판매 아이스술 아이스사는곳
# 31499  오방약국 텔레그램 pinkman114 경남드라퍼모집 코카인팝니다 파티마약하는법 케이팔아요 정글주스팔아요 창원드러그 댑
# 31500  오방약국 텔레그램 pinkman114 전라도아이스 밀크케타민도매 강동합성대마초 강남허브액상 창원엑시터시 아이스뽕하는법 코카인
# 31501  국가대표 coreaice 아이스작대기 코카인 판매처 아이스작대기 작대기주사 아이스뽕 케타민 아이스1G 사끼 엑스터시 떨사는곳 떨가격 떨팝니다 케타민 작대기술 서울아이스 빙두 필로폰파는곳 사티바 캔디판매처 케타민 아이스술 인증딜러
# 31502  텔레그램 JRice1 아이스작대기 무한 히로뽕 팝니다 반작대기 사끼 아이스작대기 케타민 엘에디 클럽파티 떨후기 떨파는곳 엑시 떨가격 차가운술 아이스얼음주사사용방법 아이스뽕 술구매 담배 마약효과 강남파티 아이스작대기 코카인
#
#        likeCount  retweetCount  viewCount  \
# 0      0.0        0.0          NaN
# 1      0.0        0.0          NaN
# 2      0.0        0.0          NaN
# 3      0.0        0.0          NaN
# 4      0.0        0.0          NaN
# ...    ...        ...           ..
# 31498  1.0        0.0           70.0
# 31499  0.0        0.0           52.0
# 31500  0.0        0.0           83.0
# 31501  0.0        0.0           41.0
# 31502  0.0        0.0           89.0
#
#                                                            hashtags  \
# 0      NaN
# 1      ['아이스', '작대기']
# 2      NaN
# 3      ['이슈', '맛집', '정보']
# 4      ['김학의', '국민의당', '특수강간범', '물뽕', '마약', '박근혜', '법무부차관', '검사출신']
# ...                                                             ...
# 31498  ['아이스술', '아이스사는곳']
# 31499  ['댑']
# 31500  ['코카인']
# 31501  ['아이스술', '인증딜러']
# 31502  ['아이스작대기', '코카인']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             media  \
# 0      NaN
# 1      [Photo(previewUrl='https://pbs.twimg.com/media/EwSU5EjVgAEq1gu?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/EwSU5EjVgAEq1gu?format=jpg&name=orig', altText=None)]
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 31498  [Photo(previewUrl='https://pbs.twimg.com/media/FsdNQNMaYAAgvOY?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FsdNQNMaYAAgvOY?format=jpg&name=orig', altText=None)]
# 31499  [Photo(previewUrl='https://pbs.twimg.com/media/Fsdck53aQAEKNbw?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/Fsdck53aQAEKNbw?format=jpg&name=orig', altText=None)]
# 31500  [Photo(previewUrl='https://pbs.twimg.com/media/Fsdc6fOakAASBp4?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/Fsdc6fOakAASBp4?format=jpg&name=orig', altText=None)]
# 31501  [Photo(previewUrl='https://pbs.twimg.com/media/FsfP-24akAAY5Q8?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FsfP-24akAAY5Q8?format=jpg&name=orig', altText=None)]
# 31502  [Video(thumbnailUrl='https://pbs.twimg.com/ext_tw_video_thumb/1641510427090915328/pu/img/unzCGHlvHisg9Z8F.jpg', variants=[VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/vid/480x640/O3jbH0l4bVCXU-AQ.mp4?tag=12', contentType='video/mp4', bitrate=950000), VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/pl/UdJmYxMIPbUECyuO.m3u8?tag=12&container=fmp4', contentType='application/x-mpegURL', bitrate=None), VideoVariant(url='https://video.twimg.com/ext_tw_video/1641510427090915328/pu/vid/320x426/Cs4cTTvKd10n9rX_.mp4?tag=12', contentType='video/mp4', bitrate=632000)], duration=0.651, views=15, altText=None)]
#
#                sourceLabel  \
# 0      Twitter Web App
# 1      Twitter Web App
# 2      Twitter Web App
# 3      Tistory2Twitter
# 4      Twitter for Android
# ...                    ...
# 31498  Twitter Web App
# 31499  Twitter Web App
# 31500  Twitter Web App
# 31501  Twitter Web App
# 31502  Twitter Web App
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   okt  \
# 0      [(카카오, Noun), (톡, Noun), (EHKT, Alpha), (15, Number), (빻, Noun), (은, Josa), (깨, Noun), (떨, Verb), (먹고, Verb), (3시, Number), (넘어서, Verb), (작대기, Noun), (소스, Noun), (를, Josa), (만들었는데, Verb), (발정, Noun), (제, Noun), (후추, Noun), (를, Josa), (더, Noun), (넣어주면, Verb), (구입, Noun), (김치, Noun), (겉잎, Noun), (으로, Josa), (꽁치, Noun), (한, Determiner), (토막, Noun), (을, Josa), (구매, Noun), (오리, Noun), (는, Josa), (와인, Noun), (숙성, Noun), (훈제오리, Noun), (더라고요, Adjective), (대마초, Noun), (한식, Noun), (이탈리아, Noun), (스페인, Noun), (태국, Noun), (요리, Noun), (의, Josa), (캔디, Noun), (가능하다니, Adjective), (실화, Noun), (인가요, Josa), (대마, Noun)]
# 1      [(카카오, Noun), (톡, Noun), (EHKT, Alpha), (살아온, Verb), (나, Noun), (의, Josa), (노력, Noun), (이, Josa), (떨, Verb), (정확한, Adjective), (재료, Noun), (의, Josa), (작대기, Noun), (완벽하게, Adjective), (적응, Noun), (이, Josa), (발정, Noun), (제, Noun), (넣고, Verb), (골고루, Adverb), (아이스, Noun), (한국, Noun), (야쿠르트, Noun), (하이, Noun), (프레, Noun), (시, Noun), (밀, Noun), (키트, Noun), (작대기, Noun), (두부김치, Noun), (해야겠어요, Verb), (', Punctuation), (대마초, Noun), (캔디, Noun), (여유롭게, Verb), (만들어, Verb), (보세요, Verb), (대마, Noun)]
# 2      [(여성, Noun), (최음제, Noun), (판매, Noun), (씨엘, Noun), (팜, Verb), (비, Noun), (닉스, Noun), (필름, Noun), (구입, Noun), (사이트, Noun), (:, Punctuation)]
# 3      [(이슈, Noun), (맛집, Noun), (정보, Noun), (피디수첩, Noun), (클럽, Noun), (유흥업소, Noun), (범죄, Noun), (에, Josa), (사용, Noun), (된, Verb), (마약, Noun), (GHB, Alpha), (물뽕, Noun), (체내, Noun), (검, Noun), (출, Verb), (되지, Verb), (않는, Verb), (성분, Noun), (오늘, Noun), (방송, Noun), (다시, Noun), (보기, Noun)]
# 4      [(김학의, Noun), (국민의당, Noun), (특수, Noun), (강간범, Noun), (물뽕, Noun), (마약, Noun), (박근혜, Noun), (정부, Noun), (법무부, Noun), (차관, Noun), (검사, Noun), (출신, Noun)]
# ...                                                                                                                                                       ...
# 31498  [(국가대표, Noun), (coreaice, Alpha), (아이스, Noun), (작대기, Noun), (코카인, Noun), (작대기, Noun), (사, Modifier), (용법, Noun), (아이스, Noun), (얼음, Noun), (주사, Noun), (인천, Noun), (아이스, Noun), (허브, Noun), (케이, Noun), (아이스, Noun), (드랍, Noun), (아이스, Noun), (작대기, Noun), (클럽, Noun), (약, Noun), (사탕, Noun), (떨, Verb), (파는, Verb), (곳, Noun), (엑스터시, Noun), (떨, Verb), (판매, Noun), (작대기, Noun), (빙, Noun), (두, Josa), (천안, Noun), (아이스, Noun), (떨, Verb), (가격, Noun), (서울, Noun), (아이스, Noun), (떨, Verb), (판매, Noun), (아이스, Noun), (술, Noun), (아이스, Noun), (사는, Verb), (곳, Noun)]
# 31499  [(오방, Noun), (약국, Noun), (텔레, Noun), (그램, Noun), (pinkman, Alpha), (114, Number), (경남, Noun), (드라퍼, Noun), (모집, Noun), (코카인, Noun), (팝니다, Verb), (파티마, Noun), (약하는, Adjective), (법, Noun), (케이, Noun), (팔아요, Verb), (정글, Noun), (주스, Noun), (팔아요, Verb), (창원, Noun), (드러, Adjective), (그, Determiner), (댑, Verb)]
# 31500  [(오방, Noun), (약국, Noun), (텔레, Noun), (그램, Noun), (pinkman, Alpha), (114, Number), (전라도, Noun), (아이스, Noun), (밀크, Noun), (케타민, Noun), (도매, Noun), (강동합, Adjective), (성, Modifier), (대마초, Noun), (강남, Noun), (허브, Noun), (액, Noun), (상, Suffix), (창원, Noun), (엑시터, Noun), (시, Noun), (아이스, Noun), (뽕, Noun), (하, Suffix), (는, Josa), (법, Noun), (코카인, Noun)]
# 31501  [(국가대표, Noun), (coreaice, Alpha), (아이스, Noun), (작대기, Noun), (코카인, Noun), (판매, Noun), (처, Noun), (아이스, Noun), (작대기, Noun), (작대기, Noun), (주사, Noun), (아이스, Noun), (뽕, Noun), (케타민, Noun), (아이스, Noun), (1, Number), (G, Alpha), (사, Modifier), (끼, Noun), (엑스터시, Noun), (떨, Verb), (사는, Verb), (곳, Noun), (떨, Verb), (가격, Noun), (떨, Verb), (팝니다, Verb), (케타민, Noun), (작, Modifier), (대, Modifier), (기술, Noun), (서울, Noun), (아이스, Noun), (빙, Noun), (두, Josa), (필로폰, Noun), (파는, Verb), (곳, Noun), (사, Modifier), (티바, Noun), (캔디, Noun), (판매, Noun), (처, Noun), (케타민, Noun), (아이스, Noun), (술, Noun), (인증, Noun), (딜러, Noun)]
# 31502  [(텔레, Noun), (그램, Noun), (JRice, Alpha), (1, Number), (아이스, Noun), (작대기, Noun), (무한, Noun), (히로뽕, Noun), (팝니다, Verb), (반작대기, Verb), (사, Modifier), (끼, Noun), (아이스, Noun), (작대기, Noun), (케타민, Noun), (엘, Noun), (에디, Noun), (클럽, Noun), (파티, Noun), (떨, Verb), (후기, Noun), (떨, Verb), (파는, Verb), (곳, Noun), (엑, Exclamation), (시, Noun), (떨, Verb), (가격, Noun), (차가운, Adjective), (술, Noun), (아이스, Noun), (얼음, Noun), (주사, Noun), (사용, Noun), (방법, Noun), (아이스, Noun), (뽕, Noun), (술, Noun), (구매, Noun), (담배, Noun), (마약, Noun), (효과, Noun), (강남, Noun), (파티, Noun), (아이스, Noun), (작대기, Noun), (코카인, Noun)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          komoran  \
# 0      [(카카오톡, NNP), (EHKT, SL), (15, SN), (빻, VV), (은, ETM), (깨, NNG), (떨, VV), (ㄹ, ETM), (먹, VV), (고, EC), (3, SN), (시, NNB), (넘, VV), (어서, EC), (작대기, NNG), (소스, NNP), (를, JKO), (만들, VV), (었, EP), (는데, EC), (발, NNG), (정제, NNP), (후추, NNP), (를, JKO), (더, MAG), (넣, VV), (어, EC), (주, VX), (면, EC), (구입, NNG), (김치, NNP), (겉, NNG), (잎, NNG), (으로, JKB), (꽁치, NNP), (한, MM), (토막, NNP), (을, JKO), (구매, NNG), (오리, NNP), (는, JX), (와인, NNP), (숙성, NNP), (훈제, NNP), (오리, VV), (더라고요, EC), (대마초, NNP), (한식, NNP), (이탈리아, NNP), (스페인, NNP), (태국, NNP), (요리, NNP), (의, JKG), (캔디, NNP), (가능, XR), (하, XSA), (다니, EC), (실화, NNG), (이, VCP), (ㄴ가요, EC), (대마, NNG)]
# 1      [(카카오톡, NNP), (EHKT, SL), (살아오, VV), (ㄴ, ETM), (나, NP), (의, JKG), (노력, NNG), (이, JKS), (떨, VV), (ㄹ, ETM), (정확, XR), (하, XSA), (ㄴ, ETM), (재료, NNP), (의, JKG), (작대기, NNG), (완벽, NNG), (하, XSV), (게, EC), (적응, NNG), (이, JKS), (발, NNG), (정제, NNP), (넣, VV), (고, EC), (골고루, MAG), (아이스, NNP), (한국, NNP), (야쿠르트, NNP), (하, NNG), (이프, NNP), (레시, NNP), (밀, NNP), (키트, NNP), (작대기, NNG), (두부김치, NNP), (하, XSV), (아야, EC), (하, VX), (겠, EP), (어요, EC), (', SS), (대마초, NNP), (캔디, NNP), (여유, NNG), (롭, XSA), (게, EC), (만들, VV), (어, EC), (보, VV), (시, EP), (어요, EC), (대마, NNG)]
# 2      [(여성, NNG), (최, XPN), (음, NNG), (제, XSN), (판매, NNG), (씨, NNB), (엘, NNP), (파, VV), (ㅁ, ETN), (비, XPN), (닉스, NNP), (필름, NNP), (구입, NNG), (사이트, NNG), (:, SP)]
# 3      [(이슈, NNG), (맛집, NNG), (정보, NNG), (피디, NNG), (수첩, NNP), (클럽, NNP), (유흥업소, NNG), (범죄, NNG), (에, JKB), (사용, NNG), (되, XSV), (ㄴ, ETM), (마약, NNP), (GHB, SL), (물, NNG), (뽕, NNG), (체내, NNG), (검출, NNG), (되, VV), (지, EC), (않, VX), (는, ETM), (성분, NNG), (오늘, NNG), (방송, NNP), (다시, NNP), (보기, NNP)]
# 4      [(김학의, NNP), (국민의당, NNP), (특수, NNP), (강간, NNP), (범, NNG), (물, NNG), (뽕, NNG), (마약, NNP), (박근혜 정부, NNP), (법무부, NNP), (차관, NNP), (검사, NNG), (출신, NNG)]
# ...                                                                                                                                                     ...
# 31498  [(국가대표, NNP), (coreaice, SL), (아이스, NNP), (작대기, NNG), (코카인, NNP), (작대기, NNG), (사용법, NNG), (아이스, NNP), (얼음, NNP), (주사, NNP), (인천, NNP), (아이스, NNP), (허브, NNP), (케이, NNP), (아이스드랍, NA), (아이스, NNP), (작대기, NNG), (클럽, NNP), (약, MM), (사탕, NNP), (떨, VV), (팔, VV), (는, ETM), (곳, NNG), (엑스터시, NNP), (떨, VV), (ㄹ, ETM), (판매, NNP), (작대기, NNG), (빙, MAG), (두, JX), (천안, NNP), (아이스, NNP), (떨, VV), (ㄹ, ETM), (가격, NNP), (서울, NNP), (아이스, NNP), (떨, VV), (ㄹ, ETM), (판매, NNP), (아이스, NNP), (술, NNG), (아이스, NNG), (살, VV), (는, ETM), (곳, NNG)]
# 31499  [(오방, NNP), (약국, NNP), (텔레그램, NNP), (pinkman, SL), (114, NNP), (경남, NNP), (들, VV), (라, EC), (푸, VV), (어, EC), (모집, NNG), (코카인, NNP), (팝, NNG), (니다, NNP), (파티마, NNP), (약, NNG), (하, XSV), (는, ETM), (법, NNB), (케이, NNP), (팔, VV), (아요, EC), (정글, NNP), (주스, NNP), (팔, VV), (아요, EC), (창원, NNP), (드, NNP), (러그, NNP), (대, VV), (업, VV)]
# 31500  [(오방, NNP), (약국, NNP), (텔레그램, NNP), (pinkman, SL), (114, NNP), (전라도, NNP), (아이스 밀크, NNP), (케타민, NNP), (도매, NNP), (강동, NNP), (합성, NNG), (대마초, NNP), (강남, NNP), (허브, NNP), (액상, NNG), (창원, NNP), (엑시, NNG), (터, NNB), (시, NNB), (아이스, NNP), (뽕, NNG), (하, XSV), (는, ETM), (법, NNB), (코카인, NNP)]
# 31501  [(국가대표, NNP), (coreaice, SL), (아이스, NNP), (작대기, NNG), (코카인, NNP), (판매처, NNG), (아이스, NNP), (작대기, NNG), (작대기, NNG), (주사, NNP), (아이스, NNP), (뽕, NNG), (케타민, NNP), (아이스, NNP), (1, SN), (G, SL), (사, NNG), (끼, NNG), (엑스터시, NNP), (떨, VV), (사, EC), (는, JX), (곳, NNG), (떨, VV), (ㄹ, ETM), (가격, NNP), (떨, VV), (파, VV), (ㅂ니다, EC), (케타민, NNP), (작대기, NNG), (술, NNG), (서울, NNP), (아이스, NNP), (빙, MAG), (두, JX), (필, NNP), (로, JKB), (폰, NNG), (팔, VV), (는, ETM), (곳, NNG), (사티, NNP), (바, NNB), (캔디, NNP), (판매처, NNG), (케타민, NNP), (아이스, NNP), (술, NNG), (인증, NNP), (딜러, NNP)]
# 31502  [(텔레그램, NNP), (JRice, SL), (1, SN), (아이스, NNP), (작대기, NNG), (무한, NNP), (히로뽕, NNG), (파, VV), (ㅂ니다, EC), (반, XPN), (작대기, NNG), (사, NNG), (끼, NNG), (아이스, NNP), (작대기, NNG), (케타민, NNP), (엘, NNP), (에디, NNP), (클럽, NNP), (파티, NNP), (떨, VV), (ㄹ, ETM), (후기, NNG), (떨, VV), (팔, VV), (는, ETM), (곳, NNG), (엑시, NNG), (떨, VV), (ㄹ, ETM), (가격, NNP), (차갑, VA), (ㄴ, ETM), (수, NNB), (ㄹ, JKO), (아이스, NNP), (얼음, NNP), (주사, NNP), (사용, NNG), (방법, NNG), (아이스, NNP), (뽕, NNG), (술, NNG), (구매, NNG), (담배, NNG), (마약, NNP), (효과, NNG), (강남, NNP), (파티, NNP), (아이스, NNP), (작대기, NNG), (코카인, NNP)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   hannanum  \
# 0      [(카카오톡, N), (EHKT, F), (15, N), (빻, P), (은, E), (깨떨, N), (먹, P), (고, E), (3시, N), (넘, P), (어서, E), (작대기, N), (소스, N), (를, J), (만들, P), (었는데, E), (발정제, N), (후추, N), (를, J), (더, M), (넣, P), (어, E), (주, P), (면, E), (구입, N), (김치, N), (겉잎, N), (으로, J), (꽁치, N), (한토막, N), (을, J), (구매, N), (오리, N), (는, J), (와인숙성훈제오리, N), (이, J), (더라고, E), (요, J), (대마초, N), (하, P), (ㄴ, E), (식, N), (이탈리아, N), (스페, N), (이, J), (ㄴ, E), (태국, N), (요리, N), (의, J), (캔디, N), (가능, N), (하, X), (다니, E), (실화, N), (이, J), (ㄴ가, E), (요, J), (대마, N)]
# 1      [(카카오톡, N), (EHKT, F), (살, P), (아, E), (오, P), (ㄴ, E), (나, N), (의, J), (노력, N), (이, J), (떨, P), (ㄹ, E), (정확한, N), (재료, N), (의, J), (작대기, N), (완벽, N), (하, X), (게, E), (적응, N), (이, J), (발정제, N), (넣, P), (고, E), (골고루, M), (아이스, N), (한국, N), (야쿠르트, N), (하이프레시, N), (밀키트, N), (작대기, N), (두부김치해야겠어요, N), (', S), (대마초, N), (캔디, N), (여유, N), (롭, X), (게, E), (만들, P), (어, E), (보, P), (세, E), (요, J), (대마, N)]
# 2      [(여성, N), (최음제, N), (판매, N), (씨엘팜, N), (비닉스, N), (필름, N), (구입, N), (사이트, N), (:, S)]
# 3      [(이슈, N), (맛집, N), (정보, N), (피디수첩, N), (클럽, N), (유흥업소, N), (범죄, N), (에, J), (사용, N), (되, X), (ㄴ, E), (마약, N), (GHB, F), (물뽕, N), (체내, N), (검출, N), (되, P), (지, E), (않, P), (는, E), (성분, N), (오늘방송, N), (다시보, N), (이, J), (기, E)]
# 4      [(김학, N), (의, J), (국민의당, N), (특수강간범, N), (물뽕, N), (마약, N), (박근혜, N), (정부, N), (법무부차관, N), (검사출신, N)]
# ...                                                                                                     ...
# 31498  [(국가대표, N), (coreaice, F), (아이스작대기, N), (코카, N), (이, J), (ㄴ, E), (작대기사용법, N), (아이스얼음주사, N), (인천아이스, N), (허브, N), (케이, N), (아이스드랍, N), (아이스작대기, N), (클럽약, N), (사탕, N), (떨파는곳, N), (엑스터시, N), (떨판매, N), (작대기, N), (빙두, N), (천안아이스, N), (떨가격, N), (서울아이스, N), (떨판매, N), (아이스술, N), (아이스사는곳, N)]
# 31499  [(오방약국, N), (텔레그램, N), (pinkman, F), (114, N), (경남드라퍼모집, N), (코카인팝니다, N), (파티마약하는법, N), (케이팔아요, N), (정글주스팔아요, N), (창원드러그, N), (댑, N)]
# 31500  [(오방약국, N), (텔레그램, N), (pinkman, F), (114, N), (전라도아이스, N), (밀크케타민도매, N), (강동합성대마초, N), (강남허브액상, N), (창원엑시터시, N), (아이스뽕하는법, N), (코카인, N)]
# 31501  [(국가대표, N), (coreaice, F), (아이스작대기, N), (코카, N), (이, J), (ㄴ, E), (판매처, N), (아이스작대기, N), (작대기주사, N), (아이스뽕, N), (케타민, N), (아이스1G, N), (사끼, N), (엑스터시, N), (떨사는곳, N), (떨가격, N), (떨팝니다, N), (케타민, N), (작대기술, N), (서울아이스, N), (빙두, N), (필로폰파는곳, N), (사티바, N), (캔디판매처, N), (케타민, N), (아이스술, N), (인증딜러, N)]
# 31502  [(텔레그램, N), (JRice1, N), (아이스작대기, N), (무한, N), (히로뽕, N), (팔, P), (ㅂ니다, E), (반작대, N), (이, J), (기, E), (사끼, N), (아이스작대기, N), (케타민, N), (엘, N), (에이, J), (디, E), (클럽파티, N), (떨후, N), (이, J), (기, E), (떨파는곳, N), (엑시, N), (떨가격, N), (차갑, P), (은, E), (술, N), (아이스얼음주사사용방법, N), (아이스뽕, N), (술구매, N), (담배, N), (마약효과, N), (강남파티, N), (아이스작대기, N), (코카인, N)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  kkma  \
# 0      [(카카오, NNG), (톡, MAG), (EHKT, OL), (15, NR), (빻, VV), (은, ETD), (깨, NNG), (떨, VV), (ㄹ, ETD), (먹, VV), (고, ECE), (3, NR), (시, NNM), (넘, VV), (어서, ECD), (작대기, NNG), (소스, NNG), (를, JKO), (만들, VV), (었, EPT), (는데, ECD), (발, NNG), (정제, NNG), (후추, NNG), (를, JKO), (더, MAG), (넣, VV), (어, ECD), (주, VXV), (면, ECE), (구입, NNG), (김치, NNG), (겉잎, NNG), (으로, JKM), (꽁치, NNG), (한, MDN), (토막, NNG), (을, JKO), (구매, NNG), (오리, NNG), (는, JX), (와인, NNG), (숙성, NNG), (훈제, NNG), (오, NNG), (리더, NNG), (라고, JX), (요, JX), (대마초, NNG), (한식, NNG), (이탈리아, NNP), (스페인, NNG), (태국, NNG), (요리, NNG), (의, JKG), (캔디, NNG), (가능, NNG), (하, XSV), (다니, EFN), (시, VV), (ㄹ, ETD), (화인, NNG), (가요, NNG), (대마, NNG)]
# 1      [(카카오, NNG), (톡, MAG), (EHKT, OL), (살아오, VV), (ㄴ, ETD), (나의, NNG), (노력, NNG), (이, JKS), (떨, VV), (ㄹ, ETD), (정확, NNG), (하, XSV), (ㄴ, ETD), (재료, NNG), (의, JKG), (작대기, NNG), (완벽, NNG), (하, XSV), (게, ECD), (적응, NNG), (이, JKS), (발정, NNG), (제, XSN), (넣, VV), (고, ECE), (골고루, MAG), (아이스, NNG), (한국, NNG), (야, NNG), (쿠르트, UN), (하이, NNG), (프, UN), (레, NNG), (시, NNG), (밀, NNG), (키트, NNG), (작대기, NNG), (두부, NNG), (김치해야겠어, UN), (요, JX), (', SS), (대마초, NNG), (캔디, NNG), (여유, NNG), (롭, XSA), (게, ECD), (만들, VV), (어, ECD), (보세, NNG), (요, JX), (대마, NNG)]
# 2      [(여성, NNG), (최음제, NNG), (판매, NNG), (씨, NNG), (엘, NNG), (파, VV), (ㅁ, ETN), (비, NNG), (닉스, NNP), (필름, NNG), (구입, NNG), (사이트, NNG), (:, SP)]
# 3      [(이슈, NNG), (맛, NNG), (집, NNG), (정보, NNG), (피디, NNG), (수첩, NNG), (클럽, NNG), (유흥업소, NNG), (범죄, NNG), (에, JKM), (사용, NNG), (되, XSV), (ㄴ, ETD), (마약, NNG), (GHB, OL), (물뽕, NNG), (체내, NNG), (검출, NNG), (되, VV), (지, ECD), (않, VXV), (는, ETD), (성분, NNG), (오늘, NNG), (방송, NNG), (다시, MAG), (보, VV), (기, ETN)]
# 4      [(김, NNG), (학, XSN), (의, JKG), (국민, NNG), (의, JKG), (당, NNG), (특수, NNG), (강간범, NNG), (물뽕, NNG), (마약, NNG), (박근, NNG), (혜, UN), (정부, NNG), (법무부, NNG), (차관, NNG), (검사, NNG), (출신, NNG)]
# ...                                                                                                                                                                                       ...
# 31498  [(국가, NNG), (대표, NNG), (coreaice, OL), (아이스, NNG), (작대기, NNG), (코카인, NNP), (작대기, NNG), (사용법, NNG), (아이스, NNG), (얼음, NNG), (주사, NNG), (인천, NNG), (아이스, NNG), (허브, NNG), (케이, NNG), (아이스, NNG), (드랍, UN), (아이스, NNG), (작대기, NNG), (클럽, NNG), (약, NNG), (사탕, NNG), (떨, VV), (ㄹ, ETD), (파, NNG), (는, JX), (곳, NNG), (엑스터시, NNG), (떨, VV), (ㄹ, ETD), (판매, NNG), (작대기, NNG), (빙, MAG), (두, MDN), (천안, NNG), (아이스, NNG), (떨, VV), (ㄹ, ETD), (가격, NNG), (서울, NNG), (아이스, NNG), (떨, VV), (ㄹ, ETD), (판매, NNG), (아이스, NNG), (술, NNG), (아이스, NNG), (사, VV), (는, ETD), (곳, NNG)]
# 31499  [(오방, NNG), (약국, NNG), (텔, UN), (레, NNG), (그램, NNM), (pinkman, OL), (114, NR), (경남, NNP), (드, VV), (라, ECD), (푸, VV), (어, ECS), (모집, NNG), (코카인, NNP), (팝, NNG), (니, VV), (다, ECS), (파티, NNG), (마약, NNG), (하, XSV), (는, ETD), (법, NNG), (케이, NNG), (팔, VV), (아요, EFN), (정글, NNG), (주스, NNG), (팔, VV), (아요, EFN), (창원, NNG), (드러그, NNG), (대, VV)]
# 31500  [(오방, NNG), (약국, NNG), (텔, UN), (레, NNG), (그램, NNM), (pinkman, OL), (114, NR), (전라도, NNG), (아이스, NNG), (밀크, NNG), (케타민, NNG), (도, JX), (매, NNG), (강동, NNP), (합성, NNG), (대마초, NNG), (강남, NNG), (허브, NNG), (액상, NNG), (창원, NNG), (엑, UN), (시, NNG), (트, VV), (어, ECS), (시, NNG), (아이스, NNG), (뽕, NNG), (하, XSV), (는, ETD), (법, NNG), (코카인, NNP)]
# 31501  [(국가, NNG), (대표, NNG), (coreaice, OL), (아이스, NNG), (작대기, NNG), (코카인, NNP), (판매처, NNG), (아이스, NNG), (작대기, NNG), (작대기, NNG), (주사, NNG), (아이스, NNG), (뽕, NNG), (케타민, NNG), (아이스, NNG), (1, NR), (G, OL), (사, VV), (아, ECS), (끼, NNG), (엑스터시, NNG), (떨, VV), (ㄹ, ETD), (살, VV), (는, ETD), (곳, NNG), (떨, VV), (ㄹ, ETD), (가격, NNG), (떨, VV), (ㄹ, ETD), (팝, NNG), (니, VV), (다, ECS), (케타민, NNG), (작대기, NNG), (술, XSN), (서울, NNG), (아이스, NNG), (빙, MAG), (두, MDN), (필로폰, NNG), (팔, VV), (는, ETD), (곳, NNG), (사, NNG), (티, NNG), (바, NNG), (캔디, NNG), (판매처, NNG), (케타민, NNG), (아이스, NNG), (술, NNG), (인증, NNG), (딜러, NNG)]
# 31502  [(텔, UN), (레, NNG), (그램, NNM), (JRice, OL), (1, NR), (아이스, NNG), (작대기, NNG), (무한, NNG), (히로뽕, NNG), (팔, VV), (ㅂ니다, EFN), (반, NNG), (작대기, NNG), (사, NNG), (끼, NNG), (아이스, NNG), (작대기, NNG), (케타민, NNG), (엘, NNG), (에, JKM), (디, NNG), (클럽, NNG), (파티, NNG), (떨, VV), (ㄹ, ETD), (후기, NNG), (떨, VV), (ㄹ, ETD), (파, NNG), (는, JX), (곳, NNG), (엑, UN), (시, NNG), (떨, VV), (ㄹ, ETD), (가격, NNG), (차갑, VA), (ㄴ, ETD), (술, NNG), (아이스, NNG), (얼음, NNG), (주사, NNG), (사용, NNG), (방법, NNG), (아이스, NNG), (뽕, NNG), (술, NNG), (구매, NNG), (담배, NNG), (마약, NNG), (효과, NNG), (강남, NNG), (파티, NNG), (아이스, NNG), (작대기, NNG), (코카인, NNP)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       mecab
# 0      [(카카오톡, NNP), (EHKT, SL), (15, SN), (빻, VV), (은, ETM), (깨, NNG), (떨, XSN), (먹, VV), (고, EC), (3, SN), (시, NNBC), (넘, VV), (어서, EC), (작대기, NNG), (소스, NNG), (를, JKO), (만들, VV), (었, EP), (는데, EC), (발정, NNG), (제, XSN), (후추, NNG), (를, JKO), (더, MAG), (넣, VV), (어, EC), (주, VX), (면, EC), (구입, NNG), (김치, NNG), (겉잎, NNG), (으로, JKB), (꽁치, NNG), (한, MM), (토막, NNBC), (을, JKO), (구매, NNG), (오리, NNG), (는, JX), (와인, NNG), (숙성, NNG), (훈제, NNG), (오리, VV), (더라고요, EC), (대마초, NNG), (한식, NNG), (이탈리아, NNP), (스페인, NNP), (태국, NNP), (요리, NNG), (의, JKG), (캔디, NNG), (가능, NNG), (하, XSA), (다니, EC), (실화, NNG), (인가요, VCP+EC), (대마, NNG)]
# 1      [(카카오톡, NNP), (EHKT, SL), (살아온, VV+ETM), (나, NP), (의, JKG), (노력, NNG), (이, JKS), (떨, VV+ETM), (정확, NNG), (한, XSA+ETM), (재료, NNG), (의, JKG), (작대기, NNG), (완벽, NNG), (하, XSA), (게, EC), (적응, NNG), (이, JKS), (발정, NNG), (제, XSN), (넣, VV), (고, EC), (골고루, MAG), (아이스, NNG), (한국, NNP), (야쿠르트, NNP), (하이프, NNP), (레시, NNP), (밀, NNP), (키트, NNP), (작대기, NNG), (두부, NNG), (김치, NNG), (해야, XSV+EC+VX), (겠, EP), (어요, EF), (', SY), (대마초, NNG), (캔디, NNG), (여유, NNG), (롭, XSA), (게, EC), (만들, VV), (어, EC), (보, VX), (세요, EP+EF), (대마, NNG)]
# 2      [(여성, NNG), (최음제, NNG), (판매, NNG), (씨엘, NNP), (팜, NNP), (비, XPN), (닉스, NNG), (필름, NNG), (구입, NNG), (사이트, NNG), (:, SC)]
# 3      [(이슈, NNG), (맛집, NNG), (정보, NNG), (피디, NNG), (수첩, NNG), (클럽, NNG), (유흥업소, NNG), (범죄, NNG), (에, JKB), (사용, NNG), (된, XSV+ETM), (마약, NNG), (GHB, SL), (물뽕, NNG), (체내, NNG), (검출, NNG), (되, VV), (지, EC), (않, VX), (는, ETM), (성분, NNG), (오늘, NNG), (방송, NNG), (다시, MAG), (보, VV), (기, ETN)]
# 4      [(김학, NNP), (의, JKG), (국민, NNG), (의, JKG), (당, NNG), (특수, NNG), (강간범, NNG), (물뽕, NNG), (마약, NNG), (박근혜, NNP), (정부, NNG), (법무부, NNG), (차관, NNG), (검사, NNG), (출신, NNG)]
# ...                                                                                                                                                                      ...
# 31498  [(국가, NNG), (대표, NNG), (coreaice, SL), (아이스, NNG), (작대기, NNG), (코카인, NNG), (작대기, NNG), (사용법, NNG), (아이스, NNG), (얼음, NNG), (주사, NNG), (인천, NNP), (아이스, NNG), (허브, NNG), (케이, NNG), (아이스, NNP), (드, NNP), (랍, NNP), (아이스, NNP), (작대기, NNG), (클럽, NNG), (약, NNG), (사탕, NNG), (떨, MAG), (파, VV), (는, ETM), (곳, NNG), (엑스터시, NNG), (떨, VV+ETM), (판매, NNG), (작대기, NNG), (빙, NNG), (두, JX), (천안, NNP), (아이스, NNG), (떨, VV+ETM), (가격, NNG), (서울, NNP), (아이스, NNG), (떨, VV+ETM), (판매, NNG), (아이스, NNG), (술, NNG), (아이스, NNG), (사, VV), (는, ETM), (곳, NNG)]
# 31499  [(오방, NNG), (약국, NNG), (텔레, NNP), (그램, NNG), (pinkman, SL), (114, SN), (경남, NNP), (드라퍼, NNP), (모집, NNG), (코카인, NNG), (팝, NNG), (니, JC), (다, MAG), (파티, NNG), (마약, NNG), (하, XSV), (는, ETM), (법, NNG), (케이, NNG), (팔, VV), (아요, EF), (정글, NNG), (주스, NNG), (팔, VV), (아요, EF), (창원, NNP), (드러그, NNG), (댑, UNKNOWN)]
# 31500  [(오방, NNG), (약국, NNG), (텔레, NNP), (그램, NNG), (pinkman, SL), (114, SN), (전라도, NNP), (아이스, NNP), (밀크, NNP), (케타민, NNG), (도매, NNG), (강, NNG), (동합, NNG), (성, XSN), (대마초, NNG), (강남, NNP), (허브, NNP), (액상, NNG), (창원, NNP), (엑, NNP), (시터, NNP), (시, NNG), (아이스, NNG), (뽕, NNG), (하, XSV), (는, ETM), (법, NNG), (코카인, NNG)]
# 31501  [(국가, NNG), (대표, NNG), (coreaice, SL), (아이스, NNG), (작대기, NNG), (코카인, NNG), (판매처, NNG), (아이스, NNG), (작대기, NNG), (작대기, NNG), (주사, NNG), (아이스, NNG), (뽕, MAG), (케타민, NNG), (아이스, NNG), (1, SN), (G, SL), (사, NR), (끼, NNBC), (엑스터시, NNG), (떨, MAG), (사, VV), (는, ETM), (곳, NNB), (떨, VV+ETM), (가격, NNG), (떨, VV+ETM), (팝, NNG), (니, JC), (다, MAG), (케타민, NNG), (작대, NNG), (기술, NNG), (서울, NNP), (아이스, NNG), (빙, MAG), (두, MM), (필로폰, NNG), (파, VV), (는, ETM), (곳, NNG), (사티, NNP), (바, NNP), (캔디, NNG), (판매처, NNG), (케타민, NNG), (아이스, NNG), (술, NNG), (인증, NNG), (딜러, NNG)]
# 31502  [(텔레, NNP), (그램, NNG), (JRice, SL), (1, SN), (아이스, NNG), (작대기, NNG), (무한, NNG), (히로뽕, NNG), (팝, NNG), (니다, VCP+EF), (반작, MAG), (대기, NNG), (사, NR), (끼, NNBC), (아이스, NNG), (작대기, NNG), (케타민, NNG), (엘, NNG), (에, JKB), (디, NNG), (클럽, NNG), (파티, NNG), (떨, VV+ETM), (후기, NNG), (떨, MAG), (파, VV), (는, ETM), (곳, NNB), (엑, IC), (시, NNG), (떨, VV+ETM), (가격, NNG), (차가운, VA+ETM), (술, NNG), (아이스, NNG), (얼음, NNG), (주사, NNG), (사용, NNG), (방법, NNG), (아이스, NNG), (뽕, MAG), (술, NNG), (구매, NNG), (담배, NNG), (마약, NNG), (효과, NNG), (강남, NNP), (파티, NNG), (아이스, NNG), (작대기, NNG), (코카인, NNG)]
#
# [31503 rows x 20 columns]

# %%
fig = plt.subplots(3,2, figsize=(20,20), sharey=True, sharex=True)


plt.subplot(321)
ax = df['okt'].map(lambda x: len(x)).hist()
ax.set_title("okt")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')


plt.subplot(322)
ax = df['komoran'].map(lambda x: len(x)).hist()
ax.set_title("komoran")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')


plt.subplot(323)
ax = df['hannanum'].map(lambda x: len(x)).hist()
ax.set_title("hannanum")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')

plt.subplot(324)
ax = df['kkma'].map(lambda x: len(x)).hist()
ax.set_title("kkma")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')

plt.subplot(325)
ax = df['mecab'].map(lambda x: len(x)).hist()
ax.set_title("mecab")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')
# Out:
# Text(0, 0.5, '빈도 수')

# %%
ax = df['mecab'].map(lambda x: len(x)).hist()
ax.set_title("mecab")
ax.set_xlabel('토큰 수')
ax.set_ylabel('빈도 수')
# Out:
# Text(0, 0.5, '빈도 수')

# %% [markdown]
# ## 형태소 통계

# %%
def tag_stat(tokenizer):
    tags = []
    for c in df[tokenizer]:
        print("c: ", c)
        for p in c:
            print("p:", p)
            tags.append(p[1])
    counter=Counter(tags)
    return counter


fig = plt.subplots(3,2, figsize=(20,20), sharex=True)


plt.subplot(321)
x, y = list(map(list, zip(*tag_stat('okt').most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set_title("okt")
ax.set(xlabel='빈도 수', ylabel='형태소')


plt.subplot(322)
x, y = list(map(list, zip(*tag_stat('komoran').most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set_title("komoran")
ax.set(xlabel='빈도 수', ylabel='형태소')


plt.subplot(323)
x, y = list(map(list, zip(*tag_stat('hannanum').most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set_title("hannanum")
ax.set(xlabel='빈도 수', ylabel='형태소')

plt.subplot(324)
x, y = list(map(list, zip(*tag_stat('kkma').most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set_title("kkma")
ax.set(xlabel='빈도 수', ylabel='형태소')

plt.subplot(325)
x, y = list(map(list, zip(*tag_stat('mecab').most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab")
ax.set(xlabel='빈도 수', ylabel='형태소')

# %% [markdown]
# ### mecab만 다시 진행

# %%
#df['mecab'] = df['mecab'].apply(lambda x: ast.literal_eval(x))

mecab = df['mecab'].to_list()
tags = []
for m in mecab:
    for p in m:
        tags.append(p[1])

# %%
import collections

counter=collections.Counter(tags)

x,y=list(map(list,zip(*counter.most_common(10))))
ax = sns.barplot(x=y,y=x)
ax.set(xlabel = '빈도 수', ylabel = '형태소')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '형태소')]

# %%
# 일반명사
def num_of_noun(noun):
    nouns = []
    for c in df['mecab']:
        for p in c:
            if p[1] == noun:
                nouns.append(p[0])
    counter = Counter(nouns)
    return counter

x, y = list(map(list, zip(*num_of_noun('NNG').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab 일반명사 NNG 빈도수")
ax.set(xlabel='빈도 수', ylabel='명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %%
x, y = list(map(list, zip(*num_of_noun('NNP').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab 고유명사 NNP 빈도수")
ax.set(xlabel='빈도 수', ylabel='명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %%
x, y = list(map(list, zip(*num_of_noun('SL').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab 외국어품사 SL 빈도수")
ax.set(xlabel='빈도 수', ylabel='외국어')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '외국어')]

# %%
# 두 글자 이상 외국어
def num_of_sl(noun):
    sl = []
    for c in df['mecab']:
        for p in c:
            if p[1] == noun and len(str(p[0])) > 1:
                sl.append(p[0])
    counter = Counter(sl)
    return counter

x, y = list(map(list, zip(*num_of_sl('SL').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab 외국어품사 SL 빈도수(2글자 이상)")
ax.set(xlabel='빈도 수', ylabel='외국어')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '외국어')]

# %% [markdown]
# # 명사 통계

# %%
def num_of_noun(tokenizer, noun):
    nouns = []
    for c in df[tokenizer]:
        for p in c:
            if p[1] == noun:
                nouns.append(p[0])
    counter = Counter(nouns)
    return counter


fig = plt.subplots(3,2, figsize=(20,20), sharex=True)

plt.subplot(321)
x, y = list(map(list, zip(*num_of_noun('okt', 'Noun').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("okt")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(322)
x, y = list(map(list, zip(*num_of_noun('komoran', 'NNP').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("komoran")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(323)
x, y = list(map(list, zip(*num_of_noun('hannanum', 'N').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("hannanum")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(324)
x, y = list(map(list, zip(*num_of_noun('kkma', 'NNG').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("kkma")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(325)
x, y = list(map(list, zip(*num_of_noun('mecab', 'NNG').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab")
ax.set(xlabel='빈도 수', ylabel='명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %% [markdown]
# # 두 글자 이상 명사 통계 (검색한 키워드를 제외)

# %%
keywords = ['스틸녹스', '신의눈물', '에토미데이트', '옥시코돈', '졸피뎀', '트라마돌', '캔디케이', '케타민', '러쉬파퍼', '랏슈', '정글주스', '엘에스디', '엑스터시', '마법의버섯', '환각버섯', '떨액', '북한산아이스', '빙두', '삥두', '사끼', '샤부', '시원한술', '아이스술', '액상떨', '작대기', '히로뽕', '크리스탈', '차가운술', '아이스', '찬술', '드라퍼', '브액', '아이스드랍', '클럽약', '텔레', '파티약', '패치', '후리베이스', '주사기', '허브', '물뽕', '발정제', '최음제', '사티바', '인디카', '합성대마', '해시시', '대마초']

def num_of_noun(tokenizer, noun):
    nouns = []
    for c in df[tokenizer]:
        for p in c:
            if p[1] == noun and len(str(p[0])) > 1 and p[0] not in keywords:
                nouns.append(p[0])
    counter = Counter(nouns)
    return counter


fig = plt.subplots(3,2, figsize=(20,20))

plt.subplot(321)
x, y = list(map(list, zip(*num_of_noun('okt', 'Noun').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("okt")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(322)
x, y = list(map(list, zip(*num_of_noun('komoran', 'NNP').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("komoran")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(323)
x, y = list(map(list, zip(*num_of_noun('hannanum', 'N').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("hannanum")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(324)
x, y = list(map(list, zip(*num_of_noun('kkma', 'NNG').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("kkma")
ax.set(xlabel='빈도 수', ylabel='명사')

plt.subplot(325)
x, y = list(map(list, zip(*num_of_noun('mecab', 'NNG').most_common(25))))
ax = sns.barplot(x=y, y=x)
ax.set_title("mecab")
ax.set(xlabel='빈도 수', ylabel='명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]
